# %% [markdown]
# # 爬PTT地震文
#
# * 需要的資訊：
#
#     1. 發文時間
#     2. 文章標題
#     3. 文章內容
#     4. 前100推推文內容
#     5. 發文者ID
#     6. 發文者IP位址
#     7. 該文是否屬於地震文（dummy）
#     8. 該文是否搶到地震爆文（dummy）
#
# * 另外要寫的功能：
#
#     1. 用IP位址反查地址資訊，回傳「縣市」（str）及經緯度（某種可以被餵進google map API的格式）
#     2. 一天／一週當中PTT上站人數的pattern，輔以「當時發文者發文所處的時間」來控制error term

# %%
# -*- coding: utf-8 -*-

# 導入 模組(module) 
import requests 
# 導入 BeautifulSoup 模組(module)：解析HTML 語法工具
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time

#from multiprocessing import Pool #https://github.com/leVirve/CrawlerTutorial
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.25.9) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
#Marvel版文章連結
url = "https://www.ptt.cc/bbs/marvel/index.html"
header_over18 = {"cookie":"over18=1"}
res = requests.get(url, headers = header_over18)
res
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(res.text, "html.parser")

# %% [markdown]
# # try to search by 推>=100

# %%
# https://www.ptt.cc/bbs/Gossiping/search?q=%E5%9C%B0%E9%9C%87 //查詢地震時的endpoint
search_endpoint_url = 'https://www.ptt.cc/bbs/marvel/search'
# 把要查詢的關鍵字參數化
resp = requests.get(search_endpoint_url, params={'q': 'recommend:100'}, headers = header_over18)

# %%
soup = BeautifulSoup(resp.text, "html.parser")

# %%
# 找到全部地震文章的連結
links = soup.find_all("a href")

# %%
titles = soup.find_all("div", "title")

# %%
for title in titles:
    print(title.text, title.a["href"])
    link = "https://www.ptt.cc/" + title.a["href"]
# Out:
# [經驗] 清醒夢裡出現一個莫名的警告
#  /bbs/marvel/M.1592506002.A.3BD.html
#
# [創作] 山村奇譚(二十五)  妖氛四起
#  /bbs/marvel/M.1592377378.A.4D6.html
#
# [創作] 詭誌-殺人夢魔(5)完
#  /bbs/marvel/M.1592344856.A.900.html
#
# [創作] 虎爺的假期
#  /bbs/marvel/M.1592284503.A.91A.html
#
# [經驗] 山上不要喊別人的全名
#  /bbs/marvel/M.1592037796.A.9E8.html
#
# [經驗] 誰在背後對我說話
#  /bbs/marvel/M.1591808833.A.431.html
#
# [創作] 詭誌-殺人夢魔(4)
#  /bbs/marvel/M.1591741243.A.27E.html
#
# [經驗] 1樓的地下室
#  /bbs/marvel/M.1591723558.A.D03.html
#
# [創作] 山村奇譚(二十四)  嚴刑逼供
#  /bbs/marvel/M.1591694670.A.6C6.html
#
# [創作] 供奉之道: 大飛往事--蜘蛛
#  /bbs/marvel/M.1591682894.A.DA4.html
#
# [經驗] 北京!北京!(二)
#  /bbs/marvel/M.1591632876.A.13A.html
#
# [經驗] 北京!北京!(一)
#  /bbs/marvel/M.1591196599.A.E32.html
#
# [創作] 倀鬼-2
#  /bbs/marvel/M.1591178582.A.B19.html
#
# [創作] 山村生活公約與住宿守則
#  /bbs/marvel/M.1591170159.A.3F2.html
#
# [創作] 詭誌-殺人夢魔(3)
#  /bbs/marvel/M.1591134960.A.8D9.html
#
# [創作] 山村奇譚(二十三)  貓咪神使
#  /bbs/marvel/M.1590981672.A.681.html
#
# Re: [經驗] 房間內的泰國娃娃
#  /bbs/marvel/M.1590943007.A.864.html
#
# [其它] 盜墓遇到長髮白衣女子蹲在旁邊低頭看你挖
#  /bbs/marvel/M.1590876934.A.95B.html
#
# [創作]自以為能遵守課後班守則是不是搞錯了什麼
#  /bbs/marvel/M.1590765905.A.308.html
#
# [創作] 供奉之城: 平天下亂
#  /bbs/marvel/M.1590730337.A.D5A.html

# %%
article_id = title.a["href"].split(sep = "/")[-1].split(sep = ".")[1]
article_id
# Out:
# '1590730337'

# %%
# 進入搜尋頁面的第一篇文章
link = "https://www.ptt.cc/" + title.a["href"]

# 18禁
#payload = {
#    "from" : "/bbs/Gossiping/index.html",
#    "yes"  : "yes"
#}
rs = requests.session()
res_subpage = rs.post("https://www.ptt.cc/ask/over18", verify = False)

res_subpage = rs.get(link, verify = False)
soup_subpage = BeautifulSoup(res_subpage.text, "html.parser")

# %%
print(soup_subpage.text)
# Out:
# [創作] 供奉之城: 平天下亂 - 看板 marvel - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 marvel
# 關於我們
# 聯絡資訊
#
#
#
#
# 返回看板
#
#
#
#
# 作者skyowl (貓頭鷹)看板marvel標題[創作] 供奉之城: 平天下亂時間Fri May 29 13:32:15 2020
#
#
# 不知不覺又逢周年   供奉之一:康爺竟然也三年了!!
#
# 不知在追、積稿、潛水朋友都還在嗎？可以幫我灑花一下XD
#
# 到週日都排班，但這日子不雙更回饋供奉的朋友，說得過去嗎？
#
#
# 所以就來加碼一篇啦~:)
#
#
#
# (防雷，兒少不宜)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Ψ
#
# 叮鈴！叮鈴！
#
#
#
# 輕柔為她別上銀耳環，銀髮簪穿過盤起華麗髮髻，輕吻氣質出眾演出者，尼姑腰際的小佛
# 鈴清脆作響。緩步告別小禮堂時，外頭下起的滂沱大雨讓中庭滿是奔跑躲雨者，霎霎雨聲
# 夾雜學生嘻嘻哈哈打鬧聲，真是青春無限讓羅蠍不捨離去。
#
#
#
# 「喂，你會回來吧？」
#
#
#
# 正要走入電梯前，沛芷喊住了她。離鋼琴獨奏會還有半個小時，去一趟萬華綽綽有餘，凝
# 視穿上黑禮服淋雨小跑步來的女孩，羅蠍信誓旦旦，「去去就回，放心。」
#
#
#
# 搖手道別，女尼右掌中兩顆蜘蛛熠熠生輝，妖光破開落日大雨無垠陰沉。電梯門關。
#
#
#
# 「超可怕的，東大之狼第三次犯案了，警察還是抓不到。」
#
#
#
# 電梯裡拿晚報的女同學憂心忡忡，另一位對玻璃梳理瀏海的則蠻不在乎，「你根本就住家
# 裡怕屁。你不知道，我租的那一間套房窗戶沒有裝鐵窗才可怕好不好。」
#
#
#
# 瞄到社會A版斗大標題正是最近聞風色變的「東大強姦案」，囂張的色狼多次侵入租屋處
# 性侵女大生得逞的案子。羅蠍沒多在意，現在艋舺局勢發展不容她分心。
#
#
#
# 叮咚！
#
#
#
# 到了8樓國文系，女同學們離去，另一位穿玄青太極道袍的歐吉桑進入電梯，他手上也拿
# 一份明顯被大力揉爛過的晚報，是社會B版「南檢一家四口一氧化碳中毒身亡」的報導，
# 羅蠍凜然問老道士，「決定一起結束這一場戰爭了嗎？」
#
#
#
# 肅然的老道只冷然一笑：「你只要……給我見到我師父就行，其餘我不保證。」
#
#
#
# 「你會如願的。」羅蠍點頭莞爾，輕輕背誦起，「我建超世志……」
#
#
#
#
#
# 叮咚！
#
#
#
# 當電梯到頂樓再次敞開時，裡頭空無一人，外頭銀河倒瀉。
#
#
#
# 決定未來五十年陰陽界弈局的最後12個小時，「神飛天夜」拉開序幕。18:04
#
#
#
# 我建超世志，必至無上道，斯願不滿足，誓不成等覺
#
#
#
#
#
#
#
#
#
#
#
#
#
# 瓢潑大雨的夜幕，正是紅衣鬼肆虐時。
#
#
#
# 諷刺的是艋舺寺燈火通明，正行史無前例的「人鬼和平會議」，而山門外頭黑茫茫無一盞
# 燈，只有一片紅通通的邪鬼群聚龍山公園，隔著一條廣州街與接管大廟的東方軍遙望，雖
# 氣氛詭譎不安可門口把守的戰士只是意興闌珊，碎嘴抱怨。
#
#
#
# 「趕快結束吧，好想回家睡覺。」
#
#
#
# 雨水沿桃木劍柄流下，希望劍沒有出鞘的機會。正道、魔道按兵不動，只等廟裡和談結果
# ，華煌明與虎姑婆如成功簽下「停戰協議」，那今晚就一點事都沒有、明晚也是、以後十
# 年很可能都是，這幾年東方和平是明證。他們都相信－－對付強大的邪惡，必然得有部份
# 犧牲，你要犧牲在戰場、屠宰場還是祭壇差別罷了。
#
#
#
# 祭壇是和平。供奉換和平，自古皆然，這不只陰陽界400年，該說是人類4000年的智慧。
#
#
#
# 叮鈴、叮鈴！
#
#
#
# 倏忽佛鈴震動，脆響在寂靜大街慢慢渲開，從西園路一段交叉口走來一排白影，魚貫出場
# 八位白袍僧由穿黃袈裟的大和尚帶隊，毫不避諱推開施工圍欄鐵架，踩上封鎖的廣州街，
# 向著正道與魔道高誦偈語：「復為大施主，普濟諸窮苦。」，黃袈裟是四大金剛的裝束。
#
#
#
# 「止步！」
#
#
#
#
#
# 黃袈裟和尚雙手合十，閃亮的大光頭恭敬鞠躬，朗聲：「華家兄弟不用怕，我佛特來支援
# 你們斬妖除魔，今夜，蕩平樂園。」，隨即袖袍抖動指向公園內群鬼，一柄如燃燒噴發熱
# 氣與光芒的金剛降魔杵刺出，準備開戰的架式不言可喻。
#
#
#
# 「禿驢，滾回西部找媽媽喝奶吧！」
#
#
#
# 「你們是奶蛋素嗎？可以喝奶不？」
#
#
#
# 紅衣鬼大聲譏笑，護衛和平使者的魔軍超過40頭鬼怪，九個和尚哪放在眼裡；同時東方軍
# 也出列一位剽悍的平頭分隊長，疾聲喝斥，「戰爭結束了，這沒你們事。」
#
#
#
# 袈裟和尚雙手再合十，「阿彌陀佛，人鬼豈能言談？此和談無異是開廟投降。」
#
#
#
# 「我說了，華家軍的事，干你……」
#
#
#
# 砰！
#
#
#
# 突然槍聲大響，正要斥責佛門的分隊長仰面倒下，他的胸口被一根燒紅的鋼針血淋淋貫穿
# ，山門口一陣驚呼，戰士們紛紛抽劍點火，劍尖游移四處找尋兇手。分隊長當場斃命。
#
#
#
# 「他媽的誰開的槍？」
#
#
#
# 明顯是灶鎗子彈所為，除東方軍的其餘部隊應該都被控制住了，自己人也不會無端放冷箭
# ；而佛門歷來鄙視灶鎗，蔑稱其為「獨夫的屠刀」；那就只剩下這幾年不斷積極竊取此咒
# 術的樂園，很合理的懷疑，劍尖下意識指向黑漆漆的龍山公園。
#
#
#
# 「大家放下劍！」標誌雄性禿的副中隊長出列穩住部隊，「去通知華司令……」
#
#
#
# 砰！
#
#
#
# 都還沒人看清楚從哪裡開槍時，槍響再起，正要下令的副中隊長滿臉驚恐，雙眼上吊，不
# 斷想看清後退的髮際線為何火辣辣，還有濃密的後腦杓為何濕漉漉……
#
#
#
# 「阿彌陀佛。」
#
#
#
# 腦漿四溢，被灶鎗炸到剩三分之一的臉龐鑲嵌一雙哀怨雙眸，好似怨嘆華司令不是說：跟
# 樂園談好，和平來臨，東方鄉下讓給鬼算了，大家調回首都撈油水、上酒店、爽爽過嗎？
# 怎麼變這樣？人鬼同根生這種屁話他也不信啊，但只要沒有戰爭、軍餉按時匯戶頭、不要
# 砍我退休金，他其實並不介意。所以到底他媽的怎會變這樣？
#
#
#
# 「媽的樂園不講信用，下三濫的惡鬼！」
#
#
#
# 「不要動手！」
#
#
#
# 東方軍陣腳大亂，連續兩位幹部被射殺，絕不是單純的誤發，明顯是要開戰，當然不能坐
# 以待斃，燒起炎劍準備跟妖魔拚殺，山門口肥頭大耳的中隊長亟欲找出對方狙擊手位置，
# 氣得頻頻大吼：「住手，找出狙擊手，到底從哪開槍的？」
#
#
#
# 「幹你娘，你們別自導自演！」
#
#
#
# 公園魔軍此時也驚慌失措，一一弓身露出森冷獸爪，夜叉抽出短斧、羅剎張開蝙蝠翅膀、
# 黑狗聲聲低鳴，帶隊的賽得壇嗥叫高呼，「冷靜、冷靜，一定是禿驢挑撥。」
#
#
#
# 「都不准動手，誰動手誰槍斃。部隊聽令，舉盾，盾舉過頭，舉過頭，動作！」
#
#
#
# 滿頭大汗的胖中隊伸出短脖找狙擊手，巴望自己能變長頸鹿，但哪是他找得到的呢？
#
#
#
# 開槍者可是從小被當刺殺者培養，18歲那一年編入北府軍得一組代碼020902，入伍不久即
# 混得「紙蓮花」揚名於陰陽，被認為是千禧年第一，與昔年「黑矢」與「六御銃殺槍」相
# 提並論的頂級狙擊修士，他要出手，豈容你們發現？
#
#
#
# 020902與大施主。
#
#
#
# 「他媽的卑鄙小人，有種出來！」
#
#
#
# 砰！
#
#
#
# 第三朵血花綻放，努力想穩定和平的軍人倒下，到頭來威脅槍斃人的中隊長，反成當晚第
# 三個被槍斃的倒楣蟲，廣州街局勢徹底崩壞，山門口陷入一片混亂。這三槍抓得恰到好處
# ，及時在停戰協議正在磋商時，徹底引爆正邪軍隊這一桶炸藥。
#
#
#
# 在混亂中不知何時遺落下三朵紙摺蓮在地，蓮花神聖，出淤泥而不染，乃是功德。
#
#
#
# 「阿彌陀佛。」九位僧人袖手旁觀，齊誦：「令彼諸群生，長夜無憂惱。」
#
#
#
# 「退、退回廟裡！」
#
#
#
#
#
# 廣州街傾盆大雨，萬千蜘蛛傾巢出。
#
#
#
#
#
# 叮鈴！
#
#
#
# 佛鈴再響，和談生變，剛聽聞槍聲雙方就惴惴不安，此時負責守門的部隊緊急撤入，對神
# 桌前的華司令放聲大呼，「司令，他們動手了，樂園朝我們開槍！」
#
#
#
# 「胡說，怎麼可能，停戰了。」
#
#
#
# 檜木凳子翻倒，華司令霍然起身，看自己部隊如熱鍋螞蟻，紅地毯被踢亂捲起，山門外擠
# 滿樂園鬼與佛門僧，一下搞不清楚怎麼回事－－這是和平會談啊，如果現在拉上廟門把虎
# 姑婆、赤練蛇關入要脅，那外頭妖魔鬼怪一定群起激憤，就完了。
#
#
#
# 剎那，佛門僧人趁隙游入艋舺寺內高唱：「我佛慈悲、特來赴援、降妖除魔！」
#
#
#
# 「是佛門，他們一來就出事！」
#
#
#
# 「幹，還我們兄弟命來！」
#
#
#
# 「幹你娘機掰哩！」
#
#
#
# 氣氛詭譎戰慄，各有主和派、主戰派對峙，也各有同袍遭擊斃的北府軍與東方軍開始罵戰
# ，越罵越難聽，一大串交雜兄弟姊妹爸媽公嬤的問候語噴出，華煌明氣到嘴唇蒼白發抖，
# 「肅靜、肅靜，通通閉嘴！」，卻怎樣也壓不住亂如菜市場的局面。
#
#
#
# 「抱歉，虎王大人，先失陪。」
#
#
#
# 華煌明勃然大怒，對滿臉疑惑的虎姑婆打了個手勢，氣沖沖來到僧人前，他認出穿黃袈裟
# 的壯漢－－曾是佛門最閃亮新星－－就是洪偉倫，他很優秀，但只要有羅蠍的地方他永遠
# 是老二。在佛門裡是這樣，學院也是這樣，二人一時瑜亮。本想要靠畢業後投入戰場去證
# 明自己，但等待他的是1988年羅蠍刺殺赤傘得手。當年的他抑鬱不得志。
#
#
#
# 「滾，艋舺寺乃華家領地，再不離開，我將合法驅逐你們。」
#
#
#
# 氣勢洶洶的華煌明用拷鬼棒怒指洪偉倫，但大和尚望向他雙眼無神，只是喃喃誦經，頃刻
# 光頭爆出一尾尾青筋，如腦殼下有無數蚯蚓竄動，緊接著熾白精魄從他體內狂涌奔流如噴
# 泉，黃袈裟「啵、啵、啵」脹得粉碎，雙肩、胸膛到後背肌肉散發耀眼的赤光懾人，如一
# 座移動火山「嗄」一下飛掠過華司令，直襲談判桌。
#
#
#
# 靈通咒．護法八大金剛
#
#
#
# 「出生眾善根，成就菩提果。」
#
#
#
# 金剛杵重重捶在野獸寬厚的脊背「嗡」一聲悶響，虎姑婆憤恨轉身一抓掃去，可貓爪卻被
# 金剛臂硬生生鉗住，金剛杵第二下將小看自己的妖魔打得頭破血流，隨虎嘯大作，酒紅色
# 西裝再藏不住偽裝紳士的姑婆與妖魔，神桌「噠」一下撞爛，又一捶下去不僅檜木桌四分
# 五裂，和平也當場化為泡影，正邪和談陡然生變。
#
#
#
# 「幹你祖宗！」
#
#
#
# EQ基本為零的虎姑婆哪耐得住，西裝服如芒果皮剝去，山貓露出兩米五的妖魔本相，還高
# 出八大金剛的靈通者一個頭，猛地虎爪寒芒閃動扣上金剛那顆頭。
#
#
#
# 「給我殺光這些破壞和平的王八！」
#
#
#
# 局勢失控，更失控的華煌明立刻指揮威逼守城軍的兩挺大灶鎗轉向八僧，可已無法服眾，
# 再忍不住的紅衣魔軍闖入廟內要營救虎團老大；同時另一條雪白人龍也飛奔過山門口，超
# 過30位佛門主力部隊一一揮舞起禪杖、念珠與寒光閃閃的戒刀，個個面無表情呼：「拯救
# 華家軍！」，過去一甲子絕不可能由他們喊出的慷慨激昂。
#
#
#
# 被削掉的頭皮噴上象徵和平的匾額，黏答答附在陰陽濃於水的「濃」字上，洪偉倫滿頭鮮
# 血繼續無畏與虎姑婆纏鬥，完全感覺不到痛苦的他只不斷複誦偈語。
#
#
#
# 「我若成正覺，立名無量壽。」
#
#
#
# 被羅蠍打擊後，聽說偉倫染上酒癮，自禪房內被搜出酒瓶後他就一而再、再而三進出地下
# 佛堂悔過，就關在羅蠍隔壁，還聽說他們和好了。這一刻，因犯戒而迷途的僧人正式回歸
# ，牽制住虎姑婆，給予佛門主力趁勢突襲進入大廟的契機。
#
#
#
# 「住手、通通住手！」
#
#
#
# 剛呼風喚雨的華煌明，現在像拿玩具的小孩在兵荒馬亂中到處找媽媽，魔軍與佛門如碰上
# 缺口的洪水淹入廟內，廝殺成一塊，守城軍也重拾武裝，投入這場壁壘不明的大戰，再沒
# 人聽信他的命令，匾額被拋棄在地來回踐踏，紅地毯熊熊燃燒散發刺鼻臭氣瀰漫，最後不
# 知哪一個不長眼的狗雜種兵一把推倒華司令在地。
#
#
#
# 「不要打了、不要再打了……」
#
#
#
# 碰巧倒臥在裝有家豪的黑色屍袋上，華煌明痛哭流涕，裝死同時久久不能自已。前院殺伐
# 一片，最後東方軍與大佛門、守城軍合流，正邪重啟戰爭，和談業已破局。
#
#
#
#
#
# 「眾生聞此號，俱來我剎中。」
#
#
#
#
#
#
#
#
# 穿過前殿的佛僧立時望見中殿後大水漫漫，粼粼水波在黑夜中格外扎眼絕望。
#
#
#
# 司瑜乘飛闆在中殿頂徘徊，水天色相連下孤軍奮戰的她一時間打不開局面，漆黑水面漂浮
# 無數猙獰人頭與斷肢殘骸，水下猖狂的人面怪魚正剝下人皮咀嚼，吃得津津有味；放肆的
# 蛇妖則囫圇吞棗，整個肚腩鼓脹如氣球，發出刺耳笑聲。
#
#
#
# 「禿驢，你們大概不知道魚肉好不好吃吧？」
#
#
#
# 如鐵達尼沉沒的現場一籌莫展，優游的人面魚精哄堂大笑，佛門僧面不改色，所有人都無
# 一絲感情波動，宛若一尊尊木偶誦唱偈語，唯有將之一一排開走出的滄桑老道面有慍色，
# 正是穿玄青太極袍的于英雄駕到，見妖魔食人為樂大怒欲狂。
#
#
#
# 「南海登天宮浪花真人在此，作惡妖孽，死。」
#
#
#
# 手握一串七枚古銅幣，于英雄盜壘似沒耽誤任何一秒就拔腿衝向大浪中，樂得魚精蛇妖捧
# 腹大笑，「老宮主被罷免，氣傻啦？」，懸空司瑜也忍不住「啊」一聲替前輩憂心，水淹
# 過兩米五龍柱，中殿裡的大小神明滅頂無數，這樣太魯莽了！
#
#
#
# 洪水汹汹捲來，于英雄靈活躍上傾倒水中的天公大香爐，身周立時浮現一圈淡藍色陣法，
# 陣法形成一堵琉璃環牆將之團團包覆，蛇尾魚鰭「啪、啪」連番掃上文風不動，浪花真人
# 一臉不屑，雙手抱胸、腳點香爐龍雕手把視滿水妖魔如無物。
#
#
#
# 古銅幣咒．七星驅魔陣
#
#
#
# 「看你能在裡面躲多久啦！」
#
#
#
# 「快用五鬼搬運夾尾巴逃吧！」
#
#
#
# 精怪叫囂，滾滾大浪一道又一道沖刷足立香爐的于英雄，如茫茫大海中的一座孤島，可他
# 連眉頭都沒皺，既沒無量神劍、也未修得六御銃殺陣仍無所無懼，右腕七枚古銅幣閃爍時
# ，包裹周身的七星陣開始朝前、後、左、右、上、下擴散推排大水，整個人墜入深淵「咚
# 」一聲壓上人孔蓋，結界對撞當場破解掉雙閃與小闀。
#
#
#
# 完全阻絕水流的老宮主輕蔑一笑，「妖孽，毋囂掰。」
#
#
#
# 「哈哈，你找死啊，跑不了吧，你知道這樣水壓多大嘛！」
#
#
#
# 好像也是科學家的人面魚鼓起蹼爪鼓掌，雖然洪水不再湧入，但現場大量積水還是將堵出
# 水孔的老宮主與驅魔陣緊緊壓在水底，水壓過大，整個人如一顆塞子動彈不得。可于英雄
# 還是無動於衷，靜靜瞅著浤浤水中蛇魚像個參觀水族館的遊客。
#
#
#
# 「再見。」
#
#
#
# 睥睨滿池虎視眈眈的妖魔，于英雄左手指天，左腕銅錢也是七枚，剎那第二組七星驅魔陣
# 展開，範圍遠超精怪想像，「呼呼」大風吹過，廣闊琉璃大陣將整個淹水的中殿涵蓋入內
# ，緊接老宮主左手握拳一擺，第二層大陣劇烈內縮，如四面八方開來50台推土機，活生生
# 把氾濫成災的大水往內擠壓，高速回溯下水位節節攀升，五米、十米逾二十米拔地而起10
# 層樓高，化為一片直徑十米的琉璃圓柱建築。
#
#
#
# 水妖察覺不對已經太遲，迅速被推動的水流拉走，兩片七星鐵壁都敲不碎之下無力地被越
# 托越高，好像變成火鍋煮開浮上的貢丸跟蟹肉棒，破口大罵，「放我們出來，于英雄你這
# 民主白賊、渣男敗類、德不配位！」
#
#
#
# 中殿忽地豎起雙層陣法，如裝滿水的瓶中瓶，于英雄安全待在小瓶子裡，上一秒叫囂的臭
# 魚爛蝦全浮在夾層內，像雜質混濁濁隨波逐流，哀鴻遍野，蔚為奇觀。
#
#
#
# 「于老宮主，求求你放我們出去，不敢作惡啦……」
#
#
#
# 古銅幣咒．雙七星驅魔陣
#
#
#
# 「叫你們別膨風。」
#
#
#
# 于英雄所在的小瓶「唰」一下消失無蹤，如瞬間拔掉塞子的洗手台，「呼嚕嚕」清爽無比
# 的水流將這批妖魔全拉入龍捲漩渦，不到幾分鐘，通通流回地下道清潔溜溜，而以五鬼搬
# 運轉移的老宮主，又站回那座屹立不搖的香爐上傲視全場。
#
#
#
# 「沒擋頭。」
#
#
#
# 很多人說年近60歲的于英雄不行了，早就不是當年那一位北抗華家、南戰赤傘的浪花真人
# 。這幾年老宮主忙於制憲、忙於統合佛道、忙於建立民主大西部，多年未酣戰沙場，甫以
# 他自己頒布的「鬥法禁制令」，這些流言好像也合情合理。
#
#
#
# 但那些散布流言的臭嘴，如果現在在這會嚇傻閉嘴，開始信仰謠言止於智者。
#
#
#
# 「好厲害……」
#
#
#
# 連這些年浸於修行的司瑜，也不得不對這位百聞不如一見的前輩喝采，光他這一手將七星
# 驅魔陣發揮淋漓盡致，用專司防守的陣法眨眼擊退一池精銳精怪，就足以證明他還是當年
# 海天子的首席弟子，蔚藍南海之下最雄偉、最美麗的浪花。
#
#
#
# －－司瑜發現她需要時間，操之過急也沒用。而且還需要夥伴，可靠的夥伴。
#
#
#
# 于英雄緊急支援下危機解除，司瑜門咒重建大廟結界。
#
#
#
# 「眾生聞此號，俱來我剎中，如佛金色身，妙相悉圓滿。」
#
#
#
# 羅蠍王牌一出，樂園鬼牌登時失去效力，不到一柱香，正道就再次拿回主導權。擊退前殿
# 政變與中殿水攻，佛門僧人再次雙手合十，朗誦偈語聲越來越高昂。
#
#
#
#
#
#
#
# 叮鈴！
#
#
#
# 鈴聲如漣漪一圈一圈波動，遽然一道玄青與雪白風暴颳起，在場即使有千里眼的修士也只
# 能捕捉到一片模糊，懂行者曉得那是五鬼搬運陣所造成的高速殘影。
#
#
#
# 在佛鈴漣漪觸碰門王玉蘭空閬之時，必成正覺第七章畫上句點。18:06。
#
#
#
#
# 「亦以大悲心，利益諸群品，離欲深正念，淨慧修梵行。」
#
#
#
# 指揮中心內，岳熔扭動身子閃避到極限，威力削弱的狼爪掠過髮梢與衣角，削鐵如泥的乘
# 風胭脂滑過頸項和臉龐，但鋒利的天閂還是無法迴避砍入背項，總指揮被巨大衝擊力斬倒
# 在地，傘與狼再次攻上，門王玉蘭揮揮手，表情意猶未盡。
#
#
#
# 「永別了，總指揮官。」
#
#
#
# 咻！
#
#
#
# 破風聲揚起，四枚黑矢凌空摜破小紅傘，白暴風颳起，雪白僧袍懸於岳熔頭頂，霎時一絲
# 如魚鉤勒住狼魔大口，「嗖」地扯翻下順勢靠蛛絲彈力俯衝，近距離嗄嗄拉弓射殺另一頭
# 紅魔狼，同時疾如閃電踩上天閂，僧袍「剝」一聲撕裂下長出恐怖三頭六臂八足「轟」地
# 將門板狠狠踩入地面，頃刻三對強弩全數瞄準門神。
#
#
#
# 絲咒．黑弩弓
#
# 佛法．阿修羅
#
#
#
# 宛若奇蹟的一氣呵成，瀟灑登場的大施主半秒內如程咬金殺出，輕鬆處理乘風胭脂、紅狼
# 衛與門神連番夾殺，一來就逆轉全局。因兩年前「捕蠍計畫」而吃大虧的羅蠍折損一條手
# 臂後，痛定思痛，特針對這種連續咒密集訓練，此刻後來反先至，即使對手升級門神也難
# 不倒她。還是老生常談，努力的天才最為可怕。
#
#
#
# 「門阿婆，好久不見。」羅蠍氣定神閒，勾勾蛛絲牽動電閘，辦公室恢復大明。
#
#
#
# 「是有點久。」門王玉蘭微微瞇眼，緩緩嘆了一口氣，「你又變得更厲害。」
#
#
#
# 9月13號傍晚，大施主出手，恰如白駒過隙的救援行動，遏止樂園斬首行動，精妙計算下
# 成功策動樂園臥底的020902、佛門子弟兵與登天宮的于英雄，讓正準備簽署媾和的停戰協
# 議胎死腹中，出手抓得快狠準不愧對得「平天下」之名。
#
#
#
# 平天下出動，滅日行動終結。
#
#
#
#
#
# 「羅小姐，終於見到你啦！」
#
#
#
# 一旁被天閂斬殺，卻像沒事的岳熔拍拍軍服的沙塵起身，鋒利門板竟然只割開他的衣服，
# 在背上留下長條形瘀血而已，笑得有點帥，但很機掰。羅蠍不禁懷疑：這傢伙不會是故意
# 在這花式受困引佛門出手吧？他到底是用甚麼擋下天閂的？
#
#
#
# －－如當時打破沙鍋搞明白，冰清門將會千秋萬世。
#
#
#
# 「臭美，誰說我想見你，滾開，我心有所屬，你不要誘惑我喔，不會上當。」
#
#
#
# 可高傲的羅蠍只是咬牙轉頭。她深深有上當感覺，大佛門像是被他釣出來的。難受。
#
#
#
# 但今晚不出手還真的不行，如岳熔被斬殺或生擒，華煌明將全盤掌控部隊，爾後也沒有華
# 家了，首都會變第四塊封疆－－樂園北方華領主－－這是最糟糕的，赤傘獨霸北府與東方
# ，離「鷸蚌相爭」最遠：反成鷸蚌合體去捕殺漁翁。一切正道與魔道和平都對蜘蛛有害，
# 正邪越和諧、戰爭越少、彼此越接近統合，羅蠍就越沒法從中獲利。
#
#
#
# －－今夜和談是、半年後停戰是。十一年後必撕毀和平的「紅色星期六」亦然。
#
#
#
# 如活在人鬼統一的太平盛世，那何來亂可平定？沒有亂，何以成就平天下亂？
#
#
#
# 算了，就算給岳熔這大叔利用一回吧。羅蠍「哼」一聲，鼓起腮幫子。
#
#
#
# 「我還得回師院看表演，老太婆你啊再不撤，等等外頭會全軍覆……」
#
#
#
# 羅蠍講到一半就被門神縱聲長笑打斷，老阿嬤目光瞥到在室外伏擊的于英雄，如狐狸的眼
# 瞇成一線，「你們以為，樂園會完全沒準備就深入敵營？少年仔，還是太菜囉。」
#
#
#
# 她旋即解除身旁的暗閘，裡頭是一開場刺殺就藏好的一只大銀箱。是真正的鬼牌。
#
#
#
# 漂浮的小傘滔天狂笑，「一次性解決掉華、佛、道的大能首領才叫斬首啊，笨蛋！」
#
#
#
# 六道鎮之關．解
#
#
#
# 兩米立方銀箱「咚」地敞開，墨綠閃電猝然落在于英雄面前，正是被囚禁的大飛。
#
#
#
# 「小雄？」
#
#
#
# 叮噹叮噹噹……叮噹叮噹噹……
#
#
#
# 綿密金屬碰撞聲不絕於耳，將佛鈴完全掩蓋，此時的大飛渾身纏滿的紅繩線串起一圈又一
# 圈的古銅幣，好似一頭綠鏽色木乃伊，再看他一舉手、一投足，古銅幣根本不止是纏身上
# ，更多的早已割破佈滿老人斑的皮膚，嵌進一坨又一坨腥紅色血痂中，渾身噴出膿瘡的劇
# 烈腥羶臭，于英雄觀之不禁駭然，顫巍巍喊了出聲。
#
#
#
# 「師父、師父我來救……」
#
#
#
# 眼前老人根本不像是人類。更多古銅幣深深鑽進棗紅色肉中，將肌肉的紋理剁得亂七八糟
# 、發臭腐爛下爬滿蒼蠅與蟲蛆，更深的一些刺到深可見骨，老人的頭蓋骨就森森泛白，露
# 出大片骷髏，連瞎去窟窿雙眸也蓋上銅幣，但還是有一道陰毒目光穿透而來，森然吐出隻
# 字片語，「小雄，呵呵呵呵，師父、誰是你師父？」
#
#
#
# 悲戚的英雄想伸手，但眼前老人可怖到連不可一世的浪花真人也感到膽怯，大飛的雙眼明
# 明已供奉給「天」，但此刻他似乎還能瞧見一切，怒瞪為小猴子辯護的小鬼頭、最疼愛的
# 大弟子通通與蜘蛛站在一起，而弟子的銀耳環不復存在。
#
#
#
# －－不管任何人跟你借、偷、搶都不准交出，懂嗎？現在去把辦公桌收一收！
#
#
#
# 那就夠了，夠了。到頭來94歲的海天子這一生還是一無所成。就是個大笑話。
#
#
#
# 「你還當我是師父？竟跟歹人混在一起，替蜘蛛為禍人間，好、好、你好！」
#
#
#
# 曾經的道派海天子平舉雙手，一串串溶入肌肉纖維的銅幣血淋淋流淌，染綠的汙血滴答落
# 滿地，須臾「喀」一聲上膛巨響，這一響聽得令人骨髓都一陣陣發冷。
#
#
#
# 「老宮主，過來我這，你師父瘋了！」
#
#
#
# 羅蠍馬上施靈通咒，喚出佛家最堅固的「金剛輪觀音」上身，轉瞬一片金光轉輪浮現身前
# 護體，比日光燈閃耀百倍。在場沒人知道大飛要幹嘛，沒有左輪槍不可能是六御銃殺陣，
# 可所有高手都寒毛直立，感受山雨欲來，連門王玉蘭都心慌啟地閉，黑色圓柱將自己與小
# 紅傘嚴密護住，似乎唯有胭脂主見過此咒疾呼，「門老太，等等閃遠點！」
#
#
#
# 射出邪光的錢幣散發深邃的墨黑光澤，于英雄無聲哭號，恍若聾啞哀望老者。
#
#
#
# 叮！噹！
#
#
#
# 啊！
#
#
#
# 海天子雙手猛然爆炸，長嘯下無數古銅幣高速朝在場正道、魔道發射，銅幣中寄宿的神明
# 被一一榨乾殆盡，爆出數倍於六御銃殺槍的威力，有如雙手各安上一挺大飛小時最喜歡的
# 格林機關槍，無差別掃射室內，無人能反擊下鎮壓住全場。
#
#
#
# 「蜘蛛！」怒慟老人眼中只剩羅蠍。
#
#
#
# 叮噹噹噹噹噹噹噹噹噹噹噹噹噹噹！
#
#
#
# 牆壁、鐵櫃、座椅應聲中槍龜裂，子彈不僅威力驚人、源源不絕、且角度難測，看似直線
# 彈道在中途高速拐彎、反彈、瞬移到不可思議完全無法防禦的360個角度命中，滿臉火燙
# 燙的門王玉蘭目睹「魔陣」陡生，從未如此興奮。
#
#
#
# 「這就是入魔？」
#
#
#
# 道，就在錢幣裡。
#
#
#
# 曾有人說：擲錢幣不公平，機率不是一半一半，如你能知曉硬幣質量、出手的角度、力道
# 、摩擦、當下氣流與濕度等等大量資訊去瞬間運算出答案，近百分之百能得知硬幣落下的
# 正反，但人終究不是電腦，做不到的－－但「魔」能。如此時的大飛將百枚錢幣軌跡運算
# 完畢，何時五顆碰一起剎那轉移、轉移到那一點散開拉四角驅邪、驅邪時又撞成七顆豎驅
# 魔鐵壁，鐵壁反彈折射又恰排六枚一串。
#
#
#
# 全盤預測，盡收眼底，滿場狙擊、例無虛發。
#
#
#
# 鈴！
#
#
#
# 一枚子彈精準敲碎腰懸的佛鈴，大施主不禁咬牙，「抱歉，我趕不回去囉。」
#
#
#
# 子彈溶入四帝、五鬼、六御與七星，轉眼門王玉蘭的地閉被從腳下的死角打翻、堅固的金
# 剛輪遭開一整排洞貫穿、空閬直接炸成片片雪花飄落，司瑜緊急救援岳熔的天閂像餅乾般
# 脆弱，片晌間整個指揮中心就如被丟入一台柏青哥機，受困於小鋼珠的槍林彈雨下永無止
# 盡，剎那的組合拼湊，所有可能悉數計算，融會貫通於全知全能的魔性下，這一刻操魔陣
# 大飛已然超越所謂「修者」的範疇。
#
#
#
# 古銅幣咒．零始滅道陣
#
#
#
# 「死！」
#
#
#
# 生雞卵無，放雞屎有，這一生毫無意義還一敗塗地的阿公喊出此生最後一個字，想把這糟
# 蹋、遺棄、鄙視、栽贓他的一切毀滅，將「道」滅。一點不留情，連最固若金湯的雙七星
# 驅魔陣也被輕易輾成粉末粒子，火燙槍口最後指向于小雄額頭。
#
#
#
# 「師父……」
#
#
#
# 明明再上一階就得道成仙，明明為山九仞可功虧一簣，但他還是不願放棄，不放棄，又過
# 不了這道檻的人最後只能墮落，悟道則封神，滅道則入魔。一線之隔。
#
#
#
# 魔化大飛．誕臨
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 戴滿古銅幣的示意圖，取自香港電影"殭屍"(2013)
#
# https://imgur.com/ObNNJDo
#
# 如有雷同純屬巧合
#
#
#
#
#
#
#
#
#
#
#
#
# 啊~大家好，我是SKYOWL
#
# 三周年其實有好多話想說，很多人想感謝，但還是留給大家說，謝天吧!
#
# 有甚麼想說的，暢所欲言喔~
#
# 有問必答(應該)~
#
#
#
#
# 僅此紀念2017.5.30~2020.5.29
#
# 希望第四年已把後傳寫完。沒餓死的話XD
#
#
#
#
#
#
# 未經授權者，不得將文章用於各種商業用途
#
# 勿入里和村。貓頭鷹:)
#
# --
# ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 114.45.151.48 (臺灣)
# ※ 文章網址: https://www.ptt.cc/bbs/marvel/M.1590730337.A.D5A.html
# 推 jack33: 頭推 05/29 13:34
# 推 NSNS: 次推 05/29 13:45
# 推 xdaymonx99: 先推 希望連載個五週年再收尾 05/29 13:51
# 推 tinyuniversy: 推！ 05/29 13:54
# 推 mitch1046: 推推推 05/29 13:57
# 推 flyinskyline: 從看一次還是覺得這架構太厲害了 05/29 13:57
# → flyinskyline: *重 05/29 13:57
# 過獎~
# 推 whisper313: 供奉必推！ 05/29 13:59
# 推 sowhat0408: 05/29 14:11
# 推 cruby841031: 推三週年~ 05/29 14:12
# 推 xdaymonx99: 看來佛鈴有破門家結界的功效 05/29 14:22
# → xdaymonx99: 看來門如月還是暗中守護著岳靖容 05/29 14:23
#
#
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
#
#
#
# (function(){window['__CF$cv$params']={r:'5a6e5a728fcf45d0',m:'f576ae195f0baf0ed0cc545e603ac292827703b7-1592749048-1800-AXxyR4O4DklCW+Q4x4ukcO/5W1sYACbNWzgWjhopTH/vhpoB/GZR5V2ZGv872uTSW9Y/+VosBOqhmlVYkI8v++cnB44V7cnUhPghoVLa4RSL7qCIeBDnb7vJCKT/cN0VJZ9di/X+goek2NHUdvxL1RrTWG9ewE0HUF/fe/UFCQ3Y',s:[0xffcd68ab39,0x5627e559d8],}})();

# %%
#一篇文章的 作者、標題、時間、看板
header = soup_subpage.find_all("span", "article-meta-value")
print(header)
# Out:
# [<span class="article-meta-value">skyowl (貓頭鷹)</span>, <span class="article-meta-value">marvel</span>, <span class="article-meta-value">[創作] 供奉之城: 平天下亂</span>, <span class="article-meta-value">Fri May 29 13:32:15 2020</span>]

# %%
print(header[0].text) #author
print(header[1].text) #board
print(header[2].text) #title
print(header[3].text) #date
# Out:
# skyowl (貓頭鷹)
# marvel
# [創作] 供奉之城: 平天下亂
# Fri May 29 13:32:15 2020

# %% [markdown]
# # 計算推噓文

# %% [markdown]
# * 推：
#
# `<span class="hl push-tag">推 </span>`
#
# * 噓：
#
# `<span class="f1 hl push-tag">噓 </span>`
#
# * 箭頭：
#
# `<span class="f1 hl push-tag">→ </span>`
#
# *ref*:
# https://medium.com/@kssk1432/ptt%E7%88%AC%E8%9F%B2%E7%B3%BB%E5%88%97-2-%E6%93%B7%E5%8F%96%E6%96%87%E7%AB%A0%E8%B3%87%E8%A8%8A-part-2-%E7%B0%A1%E5%96%AE%E8%A1%A1%E9%87%8F-18b4e78a1c7d

# %%
# push count
soup_subpage.find_all("span", {'class' : 'hl push-tag'})
# Out:
# [<span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>,
#  <span class="hl push-tag">推 </span>]

# %%
# boo count
soup_subpage.find_all("span", {'class' : 'f1 hl push-tag'})

# arrow count
#soup_subpage.find_all("span", {'class' : 'f1 hl push-tag'})
# Out:
# [<span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>,
#  <span class="f1 hl push-tag">→ </span>]

# %%
# push count
pushCount = 0
for i in soup_subpage.find_all("span", {'class' : 'hl push-tag'}):
    if "推" in i.get_text():
        pushCount+=1

# boo count
BooCount = 0
for i in soup_subpage.find_all("span", {'class' : 'f1 hl push-tag'}):
    if "噓" in i.get_text():
        BooCount+=1

# arrow count
ArrowCount = 0
for i in soup_subpage.find_all("span", {'class' : 'f1 hl push-tag'}):
    if "→" in i.get_text():
        ArrowCount+=1

# %%
print(pushCount, BooCount, ArrowCount)
# Out:
# 162 0 71

# %%
main_text = soup_subpage.find(id = "main-container").text
#print(main_text)

# %%
#推文
main_text.split(sep = "html")[1].split(sep = "\n")[1:]
# Out:
# ['推 jack33: 頭推 05/29 13:34',
#  '推 NSNS: 次推 05/29 13:45',
#  '推 xdaymonx99: 先推 希望連載個五週年再收尾 05/29 13:51',
#  '推 tinyuniversy: 推！ 05/29 13:54',
#  '推 mitch1046: 推推推 05/29 13:57',
#  '推 flyinskyline: 從看一次還是覺得這架構太厲害了 05/29 13:57',
#  '→ flyinskyline: *重 05/29 13:57',
#  '過獎~',
#  '推 whisper313: 供奉必推！ 05/29 13:59',
#  '推 sowhat0408: 05/29 14:11',
#  '推 cruby841031: 推三週年~ 05/29 14:12',
#  '推 xdaymonx99: 看來佛鈴有破門家結界的功效 05/29 14:22',
#  '→ xdaymonx99: 看來門如月還是暗中守護著岳靖容 05/29 14:23',
#  '→ xdaymonx99: 為小猴子辯護的小鬼頭應該就是岳靖容 不過他應該不算 05/29 14:24',
#  '→ xdaymonx99: 是跟蜘蛛站在一起 也許大飛沒能察覺 05/29 14:24',
#  '推 xdaymonx99: 看來零始滅道是入魔道派才會使用 真好奇胭脂主何時看 05/29 14:28',
#  '→ xdaymonx99: 過 05/29 14:28',
#  'X大爆雷專家XD',
#  '大飛已經瘋了',
#  '下回分解',
#  '',
#  '推 oozeroo: 推！ 05/29 14:29',
#  '→ xdaymonx99: 滅赤上人入魔後不知道有沒有新招 05/29 14:29',
#  '推 withoutmoon: 山村奇譚簽到完換來這裡簽到 05/29 14:35',
#  '推 w87778566: \\加碼/\\加碼/\\加碼/\\加碼/\\加碼/\\加碼/\\加碼/ 05/29 14:37',
#  '然後這周停刊:)',
#  '',
#  '推 withoutmoon: 三分鐘了 05/29 14:39',
#  '鹹蛋超人!?',
#  '推 xd070308: 推 05/29 14:42',
#  '推 withoutmoon: 3推 05/29 14:44',
#  '推 likolp: 怎麼大家都魔化了，哭喔XDDDD 05/29 14:48',
#  '人生太苦',
#  '',
#  '推 lovensr: 推 05/29 14:50',
#  '推 xdaymonx99: 這發展實在太刺激了 大飛獵殺蜘蛛的動機到底來自哪裡 05/29 14:53',
#  '→ xdaymonx99: 呢 何時發現蜘蛛的威脅性呢 05/29 14:53',
#  'X大真的盲點觀察家，下回分解',
#  '',
#  '推 withoutmoon: 推 05/29 15:02',
#  '推 withoutmoon: 現在長篇創作只看山村奇譚和供奉 05/29 15:05',
#  '我的榮幸，山村文筆超美<3',
#  '',
#  '推 withoutmoon: 推 05/29 15:07',
#  '→ withoutmoon: 推 05/29 15:08',
#  '推 onizukayukio: 先推！！太爽一個星期二更！ 05/29 15:10',
#  '朝三暮四^_^',
#  '推 withoutmoon: 推 05/29 15:11',
#  '推 upsky: 阿公喊出此生最後一個字...所以之後自願做人柱嗎？ 05/29 15:14',
#  '→ upsky: 鴉片姑跟大飛提示了什麼才入魔...最愛的小雄..不是小猴子嗎 05/29 15:14',
#  '愛大的、疼小的(也許)',
#  '人柱下下下回分解',
#  '',
#  '推 ultis: 岳熔跟羅蠍的對話又是伏筆, 05/29 15:17',
#  '→ ultis: 未來要推翻冰清門, 岳熔應該也有貢獻 05/29 15:18',
#  '讓我想起神伏筆，還是先不要(X',
#  '',
#  '推 loveyukiho: 推 05/29 15:18',
#  '推 upsky: 冰清門將會千秋萬世...門如月被林橋霆救走...可以破門神.. 05/29 15:18',
#  '→ upsky: 大飛前幾天才打贏羅歇放她走 怎現在想要滅掉蜘蛛?? 05/29 15:19',
#  '推 withoutmoon: 樓上+1滿滿疑問 05/29 15:21',
#  '推 KeyNT: 入魔的大飛只剩執念了吧.....一一a 05/29 15:32',
#  '',
#  'K大正解，入魔精神失常',
#  'U大分析一流@@!',
#  '',
#  '推 a1372213822: 未看先推 真的雙更太感人了吧 05/29 15:50',
#  '朝三暮四不要打作者',
#  '',
#  '推 v22333: 推 05/29 16:12',
#  '推 dvd0314: 灑花 05/29 16:15',
#  '3Q Flower',
#  '推 w87778566: 看到最後被圖嚇到xDDD貓頭鷹大有地雷要先說啊xDDD 05/29 16:23',
#  '哈哈抱歉，殭屍是我的封面(習慣',
#  '',
#  '推 nightwalker: 居然三週年啦     對不起我是積稿仔之一 我供奉出我 05/29 16:28',
#  '→ nightwalker: 的膝蓋 05/29 16:28',
#  '你還有一個月可以積 ((扶起',
#  '',
#  '推 balloonfly: o0爻卍煞氣a大飛卍爻0o 05/29 16:33',
#  '飛粉你好:D',
#  '',
#  '推 eli4545: 大飛最後還是入魔了QQ 05/29 16:38',
#  '不要絕望',
#  '',
#  '推 a1372213822: 恭喜三週年，希望可以一路恭喜到十週年XD 05/29 16:57',
#  '!!?!?!?不好吧XD',
#  '',
#  '推 xdaymonx99: 我覺得大飛是氣小雄把蜘蛛眼交出去 05/29 17:12',
#  '推 xdaymonx99: 鴉片姑跟大飛的對話應該都在大飛往事那篇 05/29 17:15',
#  '===供奉系===',
#  '推 ren1072: 喔喔喔喔！那個秘密會是蠱嗎？ 05/29 17:32',
#  '(眨)',
#  '',
#  '推 raysorcer: 先推 05/29 17:45',
#  '推 TRosenthal: 推 05/29 17:50',
#  '推 crazedog: 看到蜘蛛變成好人有點不習慣 05/29 17:59',
#  '推 crazedog: 現在應該剩下門如月的死法、孫韻單挑司瑜、蜘蛛大戰完 05/29 18:04',
#  '→ crazedog: 全體的胭脂主、北熔南冰的下場，最後就是門鄭胭脂三派 05/29 18:04',
#  '→ crazedog: 合體討伐冰清門跟背後大魔王蜘蛛 05/29 18:04',
#  '推 crazedog: 等等突然想到之前某一篇獨眼指揮官幫赤仙頒獎，看來岳 05/29 18:06',
#  '→ crazedog: 熔還有出場；但橋霆後來也開車去找門如月問說想知道誰 05/29 18:06',
#  '→ crazedog: 殺死你老公的嗎？看來這邊還很多故事啊 05/29 18:06',
#  '不算好人啦，這裡哪有好人(?)',
#  'C大也是爆雷專家',
#  '橋霆沒說殺你老公的吧(?)',
#  '供奉之四',
#  '',
#  '',
#  '推 withoutmoon: 推 05/29 18:11',
#  '推 withoutmoon: 推 05/29 18:14',
#  '推 withoutmoon: 推 05/29 18:16',
#  '推 withoutmoon: 推 05/29 18:17',
#  '推 achilles2550: 推！！ 05/29 18:18',
#  '推 winterherz: 魔化大飛太精彩了喔喔喔 05/29 18:35',
#  '→ winterherz: 台灣本土神魔小說第一人啊，當之無愧QQ 05/29 18:36',
#  '過譽，台灣神魔小說推日落後/噩盡島',
#  '',
#  '推 fishstay: 推 05/29 19:11',
#  '推 anonymous: 供奉真的太神了！ 05/29 19:28',
#  '過獎',
#  '推 alexstag: 大飛仙QQ 05/29 19:29',
#  'BIG FLY!Q',
#  '推 dvd0314: 推 05/29 19:39',
#  '推 TRosenthal: 推 05/29 19:46',
#  '推 nyms: 明明才複習過一次還是跟不上這資訊量ww推推 05/29 20:18',
#  '這麼可能!!!!! 看YUZU大的年表試試?!',
#  '',
#  '推 maple1108: 推 05/29 20:18',
#  '推 maple1108: 推 灑花♥☆★♬ 05/29 20:23',
#  '(接花',
#  '推 johnson02020: 很喜歡司瑜...好可惜 05/29 20:29',
#  '司瑜正在起飛(2006)',
#  '推 aeolus53: 大飛自願犧牲應該也是放下了，好辛苦的人生 05/29 20:36',
#  '甘苦甘苦',
#  '推 big8402: 大飛入魔也太強了！羅蠍鼓臉頰好可愛哈哈 05/29 20:47',
#  '竟然!',
#  '推 EdwardGein: 敘述真的神 05/29 20:58',
#  '<3<3',
#  '推 dvd0314: 推 05/29 21:17',
#  '推 jr00747848: 撒花～～有供奉真好 05/29 21:41',
#  '3Q~~~~~FLOWER!',
#  '推 TRosenthal: 推 05/29 21:59',
#  '推 jasonfju: 棒 05/29 22:10',
#  '推 yungsong: 推 05/29 22:12',
#  '推 pathrodite: 推～好震撼的大飛出場！雖然感到悲傷 05/29 22:24',
#  '煞氣的飛',
#  '推 raysorcer: 恭喜供奉滿三週年了！感謝貓頭鷹大大 05/29 22:41',
#  '謝謝支持',
#  '推 xdaymonx99: 岳熔後來應該還沒死 05/29 22:43',
#  '→ xdaymonx99: 說不定是蠱可以呼喚門如月 05/29 22:43',
#  '之後分解',
#  '推 raysorcer: 關起來時被鴉片姑問什麼是自己的道+小蘭又提到阿胭+看 05/29 22:46',
#  '→ raysorcer: 到于英雄的耳環不見，感覺不止這樣就能讓大飛爺入魔 05/29 22:46',
#  '推 raysorcer: 岳熔跟門如月和未來篇連動，供奉的伏筆越來越深了，真 05/29 22:48',
#  '→ raysorcer: 期待XD 05/29 22:48',
#  '鬼伏筆ww',
#  '下回分解大飛入魔疑問',
#  '',
#  '推 dvd0314: 推 05/29 23:08',
#  '推 mrkyo706: 大飛祖師爺，快回神啊 05/29 23:10',
#  '再也回不來惹',
#  '',
#  '推 withoutmoon: 繼 05/29 23:41',
#  '→ withoutmoon: 續 05/29 23:41',
#  '→ withoutmoon: 灌 05/29 23:41',
#  '推 raysorcer: 推 05/29 23:42',
#  '→ withoutmoon: 灌 05/29 23:43',
#  '→ withoutmoon: 灌 05/29 23:44',
#  '→ withoutmoon: 噗 05/29 23:44',
#  '推 raysorcer: 推 05/29 23:44',
#  '→ withoutmoon: 我老推不到 05/29 23:45',
#  '→ withoutmoon: 不會吧 05/29 23:46',
#  '推 withoutmoon: 再灌 05/29 23:48',
#  '',
#  '',
#  'W大謝謝你追供奉(抱)，願意給這麼多推，但真的不用占您太多時間啦XD',
#  '用灌的太熱情，其實Skyowl這樣會有壓力，我沒那麼多哽可以回覆你> <',
#  '',
#  '雖然如何推文是大家的自由...但真的，各位大大不用比作者更關心',
#  '',
#  '有沒有爆、推文多高多低，對讀者只有感謝',
#  '',
#  '不會因為推文有影響、不用灌灌也會繼續連載，真的:)',
#  '',
#  '大家適當表達，就是最好的支持:P',
#  '',
#  '希望這是最後一次討論這些瑣事，謝謝W大厚愛<3<3',
#  '',
#  '謝謝推文跟灑花的大家，我慢慢回~',
#  '',
#  '',
#  '',
#  '※ 編輯: skyowl (114.45.151.48 臺灣), 05/30/2020 00:05:07',
#  '推 btchen: 推 05/30 00:05',
#  '推 fbennyu: 推，多了好多謎團... 05/30 00:06',
#  '謎團必須的',
#  '推 deepensoul: 太強大的架構，恭喜三週年！ 供奉我的膝蓋 05/30 00:08',
#  '(扶起)',
#  '才冰山一角!',
#  '',
#  '推 withoutmoon: 啊啊 s大不用特地回我沒關係 我是看以前很多人都這 05/30 00:10',
#  '→ withoutmoon: 樣連推 05/30 00:10',
#  '→ withoutmoon: 造成壓力真對不起>< 05/30 00:11',
#  '',
#  '沒事的W大QQ，不是怪您，不用對不起啦，言重。',
#  '其實一推兩推，就很謝謝，毋須替作品擔憂:)',
#  '',
#  '也希望我回文沒給您壓力，謝謝大家願意把時間花在供奉，不管閱讀還是推文(淚目)',
#  '',
#  '三周年，特別感性> <',
#  '',
#  '',
#  '',
#  '※ 編輯: skyowl (114.45.151.48 臺灣), 05/30/2020 00:23:48',
#  '',
#  '推 a1234414: 推 05/30 00:21',
#  '推 jack999hhh95: 灑花~~ 05/30 00:38',
#  '3Q flower~~~~',
#  '推 withoutmoon: 抱歉抱歉上面有漏字 我是說以前看很多人都這樣連推 05/30 00:43',
#  '→ withoutmoon:  我才跟著這樣推 抱歉讓s大花時間回覆我>< 05/30 00:43',
#  '',
#  '別抱歉，不管幾推我都愛你們啦~~跟W大花在這篇文上推的時間相比，我這微不足道Q_QQ',
#  '',
#  '推 a1234414: 太神喇 已買書支持 05/30 00:44',
#  '感激不盡!!!',
#  '',
#  '推 yuzu: #1UcnuFZD 慶祝三周年，在年表那篇更新了全時間表 05/30 00:59',
#  '推 swordtimer: 推,感謝加碼 05/30 01:01',
#  '報答大家~',
#  '推 yuzu: 老實說有點不確定做年表是不是件好事了，因為 05/30 01:01',
#  '→ yuzu: 大量資訊裡埋藏的歷史，不斷回翻重看，是看供奉的樂趣之一。 05/30 01:02',
#  '→ yuzu: 全時間表裡列出了每個時間點的出處，方便大家索引 05/30 01:03',
#  '推 yuzu: （灑花） 05/30 01:05',
#  '',
#  '==========供奉教授==========',
#  'Y大豐富了大家的視野，萬分感謝',
#  '',
#  '推 IBERIC: 推！！！！ 恭喜三週年，不知不覺也看了三年了！ 05/30 01:56',
#  '是不是光陰如梭',
#  '',
#  '推 isle: 推 05/30 02:07',
#  '推 pandayaya: 不知不覺居然三年了啊～～～～謝謝原po給我們這麼好的 05/30 02:10',
#  '→ pandayaya: 故事 05/30 02:10',
#  '也謝謝大家一路相挺',
#  '',
#  '推 bionta: 已經三年了！恭喜！ 05/30 02:24',
#  '謝謝B大，謝謝還在~',
#  '',
#  '推 x886571: RRRRRRRRRRRRR看到大飛魔化好難過QQQQ，可是更期待貓頭鷹 05/30 02:32',
#  '→ x886571: 大還會餵什麼東西出來(? 05/30 02:32',
#  '我的榮幸!!',
#  '',
#  '推 DeaGoo: 推 不知不覺已經三週年啦 05/30 06:34',
#  '歲月不饒人~',
#  '推 weimeow1379: 魚肉齁呷某～ 嗚嗚大飛魔化了…為師父默哀五分鐘 05/30 07:19',
#  '大飛謝謝你Q',
#  '',
#  '推 esophagea198: 看到阿公魔化，好不捨，淚推！ 05/30 08:03',
#  '(遞衛生紙',
#  '',
#  '推 dvd0314: 推 05/30 09:30',
#  '推 herokado: 不...我最愛的大飛黑惹 05/30 09:41',
#  '沒黑，只是變得有錢',
#  '',
#  '推 angelicmiss: 推~☆*:.｡. o(≧▽≦)o .｡.:*☆ 05/30 09:42',
#  '☆*:.｡. o(≧▽≦)o ｡',
#  '謝謝支持',
#  '',
#  '推 aeolus53: 感覺悟道就成九九道歸，入魔就變零始滅道了XD 05/30 09:47',
#  '9/0 往上往下的選擇',
#  '',
#  '推 rainmiss2001: 大飛才是最強的 05/30 10:24',
#  '魔化ㄟ飛',
#  '推 AA64: 供奉 推 05/30 10:54',
#  '→ bugbook: 總覺得大飛自願當人柱也是為了封印蜘蛛。 05/30 11:08',
#  '這次完結會祥解',
#  '',
#  '推 dvd0314: 有愛推 05/30 11:09',
#  '<3',
#  '推 anny1031: 推！！ 05/30 11:52',
#  '推 mypumpky: 陪我走完大學的供奉推推！ 05/30 12:16',
#  '→ mypumpky: 原來三年這麼快 05/30 12:16',
#  '光陰似箭!!!!',
#  '畢業快樂',
#  '',
#  '推 pineapple824: 大飛QQQQ 05/30 12:33',
#  'QQ_Q',
#  '推 WeinoVi: 看到大飛魔化心好痛…前面還開心于英雄終於帥一波…就哭 05/30 12:38',
#  '→ WeinoVi: 了QQ 05/30 12:38',
#  '不要放棄希望(拍',
#  '我也覺得英雄本篇最帥!',
#  '',
#  '推 manno: 看前面就猜大飛八成會入魔 但希望能給大飛一個好結局 05/30 13:22',
#  '推 bionta: 覺得大飛一定不會有好結局 (幫自己打預防針) 05/30 14:02',
#  '推 car1osboozer: 都變成人柱魂飛魄散了 能有什麼好結局 05/30 14:19',
#  '',
#  '大飛的結局喔.......，這次會好好交代不爆雷，三位莫慌',
#  '其實結局不難猜吧(?)',
#  '',
#  '推 dvd0314: 推 05/30 14:42',
#  '推 bluearrow: 推推～居然三年了 05/30 19:25',
#  '時間過得太快就像龍捲風',
#  '',
#  '推 miriam0925: 推推 05/30 20:11',
#  '推 xdaymonx99: 霸子該出現救救大飛了吧嗚嗚 05/30 20:24',
#  '推 xdaymonx99: 已經點開看這篇好幾次了 越來越精彩啊啊啊 05/30 20:45',
#  '→ xdaymonx99: 最喜歡的角色就是大飛了 好想看供奉之道～ 05/30 20:46',
#  '下一篇就是供奉之道，你也太準，有天眼嗎朋友',
#  '',
#  '推 big8402: 重看了一次，這集羅蠍太可愛了，慘了要供奉給蜘蛛了嗚嗚 05/30 23:42',
#  '→ big8402: 誰來救救我RRR 05/30 23:42',
#  '哈哈哈哈哈',
#  '',
#  '許願吧B大!!!!!',
#  '',
#  '推 silverice: 推  請問這一戰過後  在場的人知道羅蠍就是蜘蛛了? 05/31 01:02',
#  '推 silverice: 知道的話 那正傳結尾 我大司瑜的風骨又輸給小蘭阿嬤了 05/31 01:10',
#  '沒有，蜘蛛絲控制眼通要到"一定程度"才能見~(或擁有寶器)',
#  '羅蠍會藏，只用大家知道的黑矢與佛咒',
#  '',
#  '推 ELF004: 問一下有沒有出實體書或電子書的計畫呀  這樣買來收藏方便 05/31 01:52',
#  '',
#  '下方有解!!!!',
#  '',
#  '推 cyndney: 恭喜三週年~本來已不追連載了，沒想到從供奉之樹開始上車 05/31 02:31',
#  '→ cyndney: ，也默默跟了貓頭鷹大二年多了... 05/31 02:31',
#  '→ cyndney: 人柱是否是魔化後悟道？很想幫大飛QQ，但也都是自己的選 05/31 02:31',
#  '→ cyndney: 擇啊！ 05/31 02:31',
#  '謝謝，少數從供奉之樹開始的!',
#  '大飛的人生真甘苦',
#  '人柱之後分解喔~',
#  '(人柱令人印象深刻!?)',
#  '推 toroyo: push 05/31 06:31',
#  '推 Kuromi0929: 好精彩啊 05/31 08:36',
#  '<3',
#  '推 silverice: 實體書第一卷(康爺到孫韻第二夜)已經上市囉 05/31 11:27',
#  '→ silverice: 第二卷應該近期也會出版了 05/31 11:28',
#  '(低調)',
#  '',
#  '推 remaxxx: 原來三年了 光陰飛逝 大飛三年前在第一系列的形象好似還 05/31 14:41',
#  '→ remaxxx: 歷歷在目。謝謝貓大神怪武俠社會故事的陪伴。有看到實體 05/31 14:41',
#  '→ remaxxx: 書一定會用力支持! 05/31 14:41',
#  '',
#  '謝謝支持!',
#  '你把供奉分類的好cool~',
#  '',
#  '推 a610570: 推啊！！！！ 05/31 21:13',
#  '推 GDUNICORN: 阿...大飛阿，于英雄阿 06/01 00:15',
#  '→ GDUNICORN: 原始天無人無我，開覺路如去如來 06/01 00:16',
#  '',
#  '===神註腳===',
#  '',
#  '推 molly41228: 這讓我想起初入媽佛版時不喜歡創作文，有掛創作2字全 06/01 03:23',
#  '→ molly41228: 都不屑一顧，看到供奉也興趣缺缺 06/01 03:23',
#  '推 molly41228: 直到供奉累積了好幾篇文，從本來寥寥無幾的推數直至 06/01 03:25',
#  '→ molly41228: 突破50、60，我才想說好ㄅ看一下好了 06/01 03:25',
#  '→ molly41228: 不看還好，一看整個晚上都不用睡了，簡直欲罷不能 06/01 03:26',
#  '推 molly41228: 龐大又不失嚴謹的設定、各種角色刻畫的活靈活現，更別 06/01 03:30',
#  '→ molly41228: 提每一篇故事都字數破表，看故事居然比我吃完麥當勞 06/01 03:30',
#  '→ molly41228: 還滿足（？） 06/01 03:30',
#  '推 molly41228: 追至一個段落後會因爲角色刻畫的太慘而難過(?)看不到 06/01 03:32',
#  '→ molly41228: 供奉而失落 06/01 03:32',
#  '→ molly41228: 從那一刻起我就知道，我愛上貓頭鷹大了（無誤） 06/01 03:33',
#  '推 molly41228: 豪然後重點就是，有你真好QQ \\\\我愛你//供奉真的拯救 06/01 03:36',
#  '→ molly41228: 我、陪我度過很多時光，拜託不要完結（欸 06/01 03:36',
#  '',
#  '',
#  '欸欸欸趁亂告白的M大，謝謝你分享心得T_T',
#  '供奉這小作品能讓大家喜歡，我也很開心:)',
#  '睡眠跟心情能跟著起伏，是作者的榮幸!',
#  '',
#  '有你真好+1 Skyowl也愛大家 (無誤!?)',
#  '但不完結的作品，難說是完整的作品啊!!!',
#  '哈哈哈太捧了，要把M大的心路歷程裱框<3',
#  '',
#  '',
#  '',
#  '推 Timmy21: 恭喜供奉三週年！ 要是連載結束一定很空虛QQ 很後期才開 06/01 10:47',
#  '→ Timmy21: 始追，最喜歡人物歷史的刻畫：對於每個角色為什麼變成後 06/01 10:47',
#  '→ Timmy21: 來那樣/追求什麼樣的道，都有清楚交代真的很不容易！貓頭 06/01 10:47',
#  '→ Timmy21: 鷹大加油，供奉一推願你能繼續創作精采的好故事。 06/01 10:47',
#  '謝謝T大的鼓勵',
#  '這種寫法其實很難討好想放鬆看點小說的讀者',
#  '是有大家一路支持才能寫自己想寫的，感激',
#  '',
#  '推 qooccc: 推 06/01 10:50',
#  '推 ARCXU: 三周年!!! 供奉真的太令人驚嘆了 06/01 10:57',
#  '千金難買吋光陰~',
#  '',
#  '推 cc22kk: 供奉!!! 06/01 12:12',
#  '推 jasonwu34: 推。 06/01 12:41',
#  '推 shawn1028: 推!!! 06/01 13:09',
#  '推 krit: 灑~ 謝謝雙更! 06/01 14:43',
#  '不謝~~~',
#  '推 t9031019901: 供奉我的膝蓋 06/01 15:00',
#  '',
#  '(扶起)',
#  '這篇膝蓋也太多!!',
#  '推 batomo: 推推 06/01 19:42',
#  '推 YuJen1997: 推！ 06/02 01:27',
#  '推 trimew: 推～ 06/02 01:58',
#  '推 edison567: 先推 06/02 12:54',
#  '推 xdaymonx99: 最近又重看了一遍供奉 仔細想想坑還蠻多的 06/02 13:33',
#  '→ xdaymonx99: 建議十週年完結差不多 06/02 13:34',
#  '會餓死在路邊XD',
#  '',
#  '推 Kun850323: 推 06/02 14:58',
#  '※ 編輯: skyowl (114.25.167.250 臺灣), 06/02/2020 19:59:18',
#  '',
#  '※ 編輯: skyowl (114.25.167.250 臺灣), 06/02/2020 20:20:49',
#  '推 romencer: 已經放棄幫大家分好人陣營或壞人陣營了（風中凌亂 06/02 20:06',
#  '→ romencer: 三週年恭喜！ㄝ 06/02 20:07',
#  '',
#  '看大家喜歡哪一種模式的供奉~',
#  '這作品，會盡量讓每種想法都發聲~',
#  '都可以是好人/壞人:)',
#  '',
#  '推 xdaymonx99: 大飛之前在跟歐陽酉對話時便已提及保護蜘蛛眼是師父 06/02 20:13',
#  '→ xdaymonx99: 遺志 06/02 20:13',
#  '→ xdaymonx99: 但在大飛往事 師父中卻看不到端倪 這也是個待填的坑呀 06/02 20:14',
#  '→ xdaymonx99: XD 06/02 20:14',
#  '推 xdaymonx99: 霸子的清澈眼只有一隻 總覺得她已使用過天眼 而且看過 06/02 20:17',
#  '→ xdaymonx99: 大飛的未來 06/02 20:17',
#  '供奉系的X大真的狂',
#  '作者來看一圈留言，獲益良多',
#  '坑太多了，還是坑天吧(?)',
#  '',
#  '※ 編輯: skyowl (114.25.167.250 臺灣), 06/02/2020 20:29:04',
#  '推 loona: 魔化大飛好像有點帥 06/03 08:24',
#  '魔化才帥:P',
#  '',
#  '推 xdaymonx99: 回romencer大 我覺得供奉中沒有絕對的好人和惡人 每一 06/03 10:40',
#  '→ xdaymonx99: 個人物都有自己的性格、過去、故事、改變和追求的事 06/03 10:40',
#  '→ xdaymonx99: 物 在這漫長的歷史中慢慢地形塑出每一個不同的人物 即 06/03 10:40',
#  '→ xdaymonx99: 使是看起來最惡的血姬也有在鄭家遭受輕視的過去 最善 06/03 10:40',
#  '→ xdaymonx99: 的司瑜也有狂熱的權力慾 06/03 10:40',
#  'X大的留言，我都覺得可以集合起來當書評(鞠躬)',
#  '',
#  '推 ralfin: 三年了，恭喜啊！來支持一下實體書 06/03 12:31',
#  '感激不盡!!!',
#  '',
#  '推 a950240: 停刊：（（ 06/04 09:39',
#  ':)',
#  '推 hoyo: 岳熔跟門如月婚後，不曉得有沒有順便當大盾。 06/04 11:40',
#  '推 KeyNT: 沒喔，岳熔婚後也仍然沒進行入門儀式。 06/04 17:07',
#  '',
#  '沒錯，要有儀式與紅劊認可~',
#  '不過他對門咒研究蠻深der',
#  '',
#  '推 dmes07: 最近在複習前面的章節，再回頭看發現好多伏筆非常可喜。一 06/06 00:36',
#  '→ dmes07: 直忍著不看最新回，一看就是我最愛的大飛魔化啊…嗚嗚嗚。 06/06 00:36',
#  '→ dmes07: 滅赤上人還有恨跟爭的心，可大飛真的只是過不了現實的關 06/06 00:36',
#  '→ dmes07: 啊…也許沒有辦法絕情的人，終究是無法得道的：( 06/06 00:36',
#  '你的解釋好棒QQ',
#  '不過大飛還有戲啦~別絕望!!',
#  '',
#  '推 Narcocat: 感謝貓頭鷹大寫出這麼棒的故事！ 06/07 00:16',
#  '推 Narcocat: 原來三週年了！回想這三年多來不在台灣的日子很多 06/07 00:45',
#  '→ Narcocat: 靠著飄版跟供奉讓我不時享受來自故鄉的溫暖，再次感謝 06/07 00:46',
#  '深有同感!',
#  '在異鄉時，供奉也幫助我很多(握手)',
#  '※ 編輯: skyowl (114.45.153.34 臺灣), 06/14/2020 16:16:36',
#  '',
#  '',
#  '']

# %%
# 把整個內容切割透過 "-- " 切割成2個陣列
pre_text = main_text.split('--')[0]
    
# 把每段文字 根據 '\n' 切開
texts = pre_text.split('\n')
# 如果你爬多篇你會發現 
contents = texts[2:]
# 內容
content = '\n'.join(contents)

print('內容：'+content)
# Out:
# 內容：
#
# 不知不覺又逢周年   供奉之一:康爺竟然也三年了!!
#
# 不知在追、積稿、潛水朋友都還在嗎？可以幫我灑花一下XD
#
# 到週日都排班，但這日子不雙更回饋供奉的朋友，說得過去嗎？
#
#
# 所以就來加碼一篇啦~:)
#
#
#
# (防雷，兒少不宜)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Ψ
#
# 叮鈴！叮鈴！
#
#
#
# 輕柔為她別上銀耳環，銀髮簪穿過盤起華麗髮髻，輕吻氣質出眾演出者，尼姑腰際的小佛
# 鈴清脆作響。緩步告別小禮堂時，外頭下起的滂沱大雨讓中庭滿是奔跑躲雨者，霎霎雨聲
# 夾雜學生嘻嘻哈哈打鬧聲，真是青春無限讓羅蠍不捨離去。
#
#
#
# 「喂，你會回來吧？」
#
#
#
# 正要走入電梯前，沛芷喊住了她。離鋼琴獨奏會還有半個小時，去一趟萬華綽綽有餘，凝
# 視穿上黑禮服淋雨小跑步來的女孩，羅蠍信誓旦旦，「去去就回，放心。」
#
#
#
# 搖手道別，女尼右掌中兩顆蜘蛛熠熠生輝，妖光破開落日大雨無垠陰沉。電梯門關。
#
#
#
# 「超可怕的，東大之狼第三次犯案了，警察還是抓不到。」
#
#
#
# 電梯裡拿晚報的女同學憂心忡忡，另一位對玻璃梳理瀏海的則蠻不在乎，「你根本就住家
# 裡怕屁。你不知道，我租的那一間套房窗戶沒有裝鐵窗才可怕好不好。」
#
#
#
# 瞄到社會A版斗大標題正是最近聞風色變的「東大強姦案」，囂張的色狼多次侵入租屋處
# 性侵女大生得逞的案子。羅蠍沒多在意，現在艋舺局勢發展不容她分心。
#
#
#
# 叮咚！
#
#
#
# 到了8樓國文系，女同學們離去，另一位穿玄青太極道袍的歐吉桑進入電梯，他手上也拿
# 一份明顯被大力揉爛過的晚報，是社會B版「南檢一家四口一氧化碳中毒身亡」的報導，
# 羅蠍凜然問老道士，「決定一起結束這一場戰爭了嗎？」
#
#
#
# 肅然的老道只冷然一笑：「你只要……給我見到我師父就行，其餘我不保證。」
#
#
#
# 「你會如願的。」羅蠍點頭莞爾，輕輕背誦起，「我建超世志……」
#
#
#
#
#
# 叮咚！
#
#
#
# 當電梯到頂樓再次敞開時，裡頭空無一人，外頭銀河倒瀉。
#
#
#
# 決定未來五十年陰陽界弈局的最後12個小時，「神飛天夜」拉開序幕。18:04
#
#
#
# 我建超世志，必至無上道，斯願不滿足，誓不成等覺
#
#
#
#
#
#
#
#
#
#
#
#
#
# 瓢潑大雨的夜幕，正是紅衣鬼肆虐時。
#
#
#
# 諷刺的是艋舺寺燈火通明，正行史無前例的「人鬼和平會議」，而山門外頭黑茫茫無一盞
# 燈，只有一片紅通通的邪鬼群聚龍山公園，隔著一條廣州街與接管大廟的東方軍遙望，雖
# 氣氛詭譎不安可門口把守的戰士只是意興闌珊，碎嘴抱怨。
#
#
#
# 「趕快結束吧，好想回家睡覺。」
#
#
#
# 雨水沿桃木劍柄流下，希望劍沒有出鞘的機會。正道、魔道按兵不動，只等廟裡和談結果
# ，華煌明與虎姑婆如成功簽下「停戰協議」，那今晚就一點事都沒有、明晚也是、以後十
# 年很可能都是，這幾年東方和平是明證。他們都相信－－對付強大的邪惡，必然得有部份
# 犧牲，你要犧牲在戰場、屠宰場還是祭壇差別罷了。
#
#
#
# 祭壇是和平。供奉換和平，自古皆然，這不只陰陽界400年，該說是人類4000年的智慧。
#
#
#
# 叮鈴、叮鈴！
#
#
#
# 倏忽佛鈴震動，脆響在寂靜大街慢慢渲開，從西園路一段交叉口走來一排白影，魚貫出場
# 八位白袍僧由穿黃袈裟的大和尚帶隊，毫不避諱推開施工圍欄鐵架，踩上封鎖的廣州街，
# 向著正道與魔道高誦偈語：「復為大施主，普濟諸窮苦。」，黃袈裟是四大金剛的裝束。
#
#
#
# 「止步！」
#
#
#
#
#
# 黃袈裟和尚雙手合十，閃亮的大光頭恭敬鞠躬，朗聲：「華家兄弟不用怕，我佛特來支援
# 你們斬妖除魔，今夜，蕩平樂園。」，隨即袖袍抖動指向公園內群鬼，一柄如燃燒噴發熱
# 氣與光芒的金剛降魔杵刺出，準備開戰的架式不言可喻。
#
#
#
# 「禿驢，滾回西部找媽媽喝奶吧！」
#
#
#
# 「你們是奶蛋素嗎？可以喝奶不？」
#
#
#
# 紅衣鬼大聲譏笑，護衛和平使者的魔軍超過40頭鬼怪，九個和尚哪放在眼裡；同時東方軍
# 也出列一位剽悍的平頭分隊長，疾聲喝斥，「戰爭結束了，這沒你們事。」
#
#
#
# 袈裟和尚雙手再合十，「阿彌陀佛，人鬼豈能言談？此和談無異是開廟投降。」
#
#
#
# 「我說了，華家軍的事，干你……」
#
#
#
# 砰！
#
#
#
# 突然槍聲大響，正要斥責佛門的分隊長仰面倒下，他的胸口被一根燒紅的鋼針血淋淋貫穿
# ，山門口一陣驚呼，戰士們紛紛抽劍點火，劍尖游移四處找尋兇手。分隊長當場斃命。
#
#
#
# 「他媽的誰開的槍？」
#
#
#
# 明顯是灶鎗子彈所為，除東方軍的其餘部隊應該都被控制住了，自己人也不會無端放冷箭
# ；而佛門歷來鄙視灶鎗，蔑稱其為「獨夫的屠刀」；那就只剩下這幾年不斷積極竊取此咒
# 術的樂園，很合理的懷疑，劍尖下意識指向黑漆漆的龍山公園。
#
#
#
# 「大家放下劍！」標誌雄性禿的副中隊長出列穩住部隊，「去通知華司令……」
#
#
#
# 砰！
#
#
#
# 都還沒人看清楚從哪裡開槍時，槍響再起，正要下令的副中隊長滿臉驚恐，雙眼上吊，不
# 斷想看清後退的髮際線為何火辣辣，還有濃密的後腦杓為何濕漉漉……
#
#
#
# 「阿彌陀佛。」
#
#
#
# 腦漿四溢，被灶鎗炸到剩三分之一的臉龐鑲嵌一雙哀怨雙眸，好似怨嘆華司令不是說：跟
# 樂園談好，和平來臨，東方鄉下讓給鬼算了，大家調回首都撈油水、上酒店、爽爽過嗎？
# 怎麼變這樣？人鬼同根生這種屁話他也不信啊，但只要沒有戰爭、軍餉按時匯戶頭、不要
# 砍我退休金，他其實並不介意。所以到底他媽的怎會變這樣？
#
#
#
# 「媽的樂園不講信用，下三濫的惡鬼！」
#
#
#
# 「不要動手！」
#
#
#
# 東方軍陣腳大亂，連續兩位幹部被射殺，絕不是單純的誤發，明顯是要開戰，當然不能坐
# 以待斃，燒起炎劍準備跟妖魔拚殺，山門口肥頭大耳的中隊長亟欲找出對方狙擊手位置，
# 氣得頻頻大吼：「住手，找出狙擊手，到底從哪開槍的？」
#
#
#
# 「幹你娘，你們別自導自演！」
#
#
#
# 公園魔軍此時也驚慌失措，一一弓身露出森冷獸爪，夜叉抽出短斧、羅剎張開蝙蝠翅膀、
# 黑狗聲聲低鳴，帶隊的賽得壇嗥叫高呼，「冷靜、冷靜，一定是禿驢挑撥。」
#
#
#
# 「都不准動手，誰動手誰槍斃。部隊聽令，舉盾，盾舉過頭，舉過頭，動作！」
#
#
#
# 滿頭大汗的胖中隊伸出短脖找狙擊手，巴望自己能變長頸鹿，但哪是他找得到的呢？
#
#
#
# 開槍者可是從小被當刺殺者培養，18歲那一年編入北府軍得一組代碼020902，入伍不久即
# 混得「紙蓮花」揚名於陰陽，被認為是千禧年第一，與昔年「黑矢」與「六御銃殺槍」相
# 提並論的頂級狙擊修士，他要出手，豈容你們發現？
#
#
#
# 020902與大施主。
#
#
#
# 「他媽的卑鄙小人，有種出來！」
#
#
#
# 砰！
#
#
#
# 第三朵血花綻放，努力想穩定和平的軍人倒下，到頭來威脅槍斃人的中隊長，反成當晚第
# 三個被槍斃的倒楣蟲，廣州街局勢徹底崩壞，山門口陷入一片混亂。這三槍抓得恰到好處
# ，及時在停戰協議正在磋商時，徹底引爆正邪軍隊這一桶炸藥。
#
#
#
# 在混亂中不知何時遺落下三朵紙摺蓮在地，蓮花神聖，出淤泥而不染，乃是功德。
#
#
#
# 「阿彌陀佛。」九位僧人袖手旁觀，齊誦：「令彼諸群生，長夜無憂惱。」
#
#
#
# 「退、退回廟裡！」
#
#
#
#
#
# 廣州街傾盆大雨，萬千蜘蛛傾巢出。
#
#
#
#
#
# 叮鈴！
#
#
#
# 佛鈴再響，和談生變，剛聽聞槍聲雙方就惴惴不安，此時負責守門的部隊緊急撤入，對神
# 桌前的華司令放聲大呼，「司令，他們動手了，樂園朝我們開槍！」
#
#
#
# 「胡說，怎麼可能，停戰了。」
#
#
#
# 檜木凳子翻倒，華司令霍然起身，看自己部隊如熱鍋螞蟻，紅地毯被踢亂捲起，山門外擠
# 滿樂園鬼與佛門僧，一下搞不清楚怎麼回事－－這是和平會談啊，如果現在拉上廟門把虎
# 姑婆、赤練蛇關入要脅，那外頭妖魔鬼怪一定群起激憤，就完了。
#
#
#
# 剎那，佛門僧人趁隙游入艋舺寺內高唱：「我佛慈悲、特來赴援、降妖除魔！」
#
#
#
# 「是佛門，他們一來就出事！」
#
#
#
# 「幹，還我們兄弟命來！」
#
#
#
# 「幹你娘機掰哩！」
#
#
#
# 氣氛詭譎戰慄，各有主和派、主戰派對峙，也各有同袍遭擊斃的北府軍與東方軍開始罵戰
# ，越罵越難聽，一大串交雜兄弟姊妹爸媽公嬤的問候語噴出，華煌明氣到嘴唇蒼白發抖，
# 「肅靜、肅靜，通通閉嘴！」，卻怎樣也壓不住亂如菜市場的局面。
#
#
#
# 「抱歉，虎王大人，先失陪。」
#
#
#
# 華煌明勃然大怒，對滿臉疑惑的虎姑婆打了個手勢，氣沖沖來到僧人前，他認出穿黃袈裟
# 的壯漢－－曾是佛門最閃亮新星－－就是洪偉倫，他很優秀，但只要有羅蠍的地方他永遠
# 是老二。在佛門裡是這樣，學院也是這樣，二人一時瑜亮。本想要靠畢業後投入戰場去證
# 明自己，但等待他的是1988年羅蠍刺殺赤傘得手。當年的他抑鬱不得志。
#
#
#
# 「滾，艋舺寺乃華家領地，再不離開，我將合法驅逐你們。」
#
#
#
# 氣勢洶洶的華煌明用拷鬼棒怒指洪偉倫，但大和尚望向他雙眼無神，只是喃喃誦經，頃刻
# 光頭爆出一尾尾青筋，如腦殼下有無數蚯蚓竄動，緊接著熾白精魄從他體內狂涌奔流如噴
# 泉，黃袈裟「啵、啵、啵」脹得粉碎，雙肩、胸膛到後背肌肉散發耀眼的赤光懾人，如一
# 座移動火山「嗄」一下飛掠過華司令，直襲談判桌。
#
#
#
# 靈通咒．護法八大金剛
#
#
#
# 「出生眾善根，成就菩提果。」
#
#
#
# 金剛杵重重捶在野獸寬厚的脊背「嗡」一聲悶響，虎姑婆憤恨轉身一抓掃去，可貓爪卻被
# 金剛臂硬生生鉗住，金剛杵第二下將小看自己的妖魔打得頭破血流，隨虎嘯大作，酒紅色
# 西裝再藏不住偽裝紳士的姑婆與妖魔，神桌「噠」一下撞爛，又一捶下去不僅檜木桌四分
# 五裂，和平也當場化為泡影，正邪和談陡然生變。
#
#
#
# 「幹你祖宗！」
#
#
#
# EQ基本為零的虎姑婆哪耐得住，西裝服如芒果皮剝去，山貓露出兩米五的妖魔本相，還高
# 出八大金剛的靈通者一個頭，猛地虎爪寒芒閃動扣上金剛那顆頭。
#
#
#
# 「給我殺光這些破壞和平的王八！」
#
#
#
# 局勢失控，更失控的華煌明立刻指揮威逼守城軍的兩挺大灶鎗轉向八僧，可已無法服眾，
# 再忍不住的紅衣魔軍闖入廟內要營救虎團老大；同時另一條雪白人龍也飛奔過山門口，超
# 過30位佛門主力部隊一一揮舞起禪杖、念珠與寒光閃閃的戒刀，個個面無表情呼：「拯救
# 華家軍！」，過去一甲子絕不可能由他們喊出的慷慨激昂。
#
#
#
# 被削掉的頭皮噴上象徵和平的匾額，黏答答附在陰陽濃於水的「濃」字上，洪偉倫滿頭鮮
# 血繼續無畏與虎姑婆纏鬥，完全感覺不到痛苦的他只不斷複誦偈語。
#
#
#
# 「我若成正覺，立名無量壽。」
#
#
#
# 被羅蠍打擊後，聽說偉倫染上酒癮，自禪房內被搜出酒瓶後他就一而再、再而三進出地下
# 佛堂悔過，就關在羅蠍隔壁，還聽說他們和好了。這一刻，因犯戒而迷途的僧人正式回歸
# ，牽制住虎姑婆，給予佛門主力趁勢突襲進入大廟的契機。
#
#
#
# 「住手、通通住手！」
#
#
#
# 剛呼風喚雨的華煌明，現在像拿玩具的小孩在兵荒馬亂中到處找媽媽，魔軍與佛門如碰上
# 缺口的洪水淹入廟內，廝殺成一塊，守城軍也重拾武裝，投入這場壁壘不明的大戰，再沒
# 人聽信他的命令，匾額被拋棄在地來回踐踏，紅地毯熊熊燃燒散發刺鼻臭氣瀰漫，最後不
# 知哪一個不長眼的狗雜種兵一把推倒華司令在地。
#
#
#
# 「不要打了、不要再打了……」
#
#
#
# 碰巧倒臥在裝有家豪的黑色屍袋上，華煌明痛哭流涕，裝死同時久久不能自已。前院殺伐
# 一片，最後東方軍與大佛門、守城軍合流，正邪重啟戰爭，和談業已破局。
#
#
#
#
#
# 「眾生聞此號，俱來我剎中。」
#
#
#
#
#
#
#
#
# 穿過前殿的佛僧立時望見中殿後大水漫漫，粼粼水波在黑夜中格外扎眼絕望。
#
#
#
# 司瑜乘飛闆在中殿頂徘徊，水天色相連下孤軍奮戰的她一時間打不開局面，漆黑水面漂浮
# 無數猙獰人頭與斷肢殘骸，水下猖狂的人面怪魚正剝下人皮咀嚼，吃得津津有味；放肆的
# 蛇妖則囫圇吞棗，整個肚腩鼓脹如氣球，發出刺耳笑聲。
#
#
#
# 「禿驢，你們大概不知道魚肉好不好吃吧？」
#
#
#
# 如鐵達尼沉沒的現場一籌莫展，優游的人面魚精哄堂大笑，佛門僧面不改色，所有人都無
# 一絲感情波動，宛若一尊尊木偶誦唱偈語，唯有將之一一排開走出的滄桑老道面有慍色，
# 正是穿玄青太極袍的于英雄駕到，見妖魔食人為樂大怒欲狂。
#
#
#
# 「南海登天宮浪花真人在此，作惡妖孽，死。」
#
#
#
# 手握一串七枚古銅幣，于英雄盜壘似沒耽誤任何一秒就拔腿衝向大浪中，樂得魚精蛇妖捧
# 腹大笑，「老宮主被罷免，氣傻啦？」，懸空司瑜也忍不住「啊」一聲替前輩憂心，水淹
# 過兩米五龍柱，中殿裡的大小神明滅頂無數，這樣太魯莽了！
#
#
#
# 洪水汹汹捲來，于英雄靈活躍上傾倒水中的天公大香爐，身周立時浮現一圈淡藍色陣法，
# 陣法形成一堵琉璃環牆將之團團包覆，蛇尾魚鰭「啪、啪」連番掃上文風不動，浪花真人
# 一臉不屑，雙手抱胸、腳點香爐龍雕手把視滿水妖魔如無物。
#
#
#
# 古銅幣咒．七星驅魔陣
#
#
#
# 「看你能在裡面躲多久啦！」
#
#
#
# 「快用五鬼搬運夾尾巴逃吧！」
#
#
#
# 精怪叫囂，滾滾大浪一道又一道沖刷足立香爐的于英雄，如茫茫大海中的一座孤島，可他
# 連眉頭都沒皺，既沒無量神劍、也未修得六御銃殺陣仍無所無懼，右腕七枚古銅幣閃爍時
# ，包裹周身的七星陣開始朝前、後、左、右、上、下擴散推排大水，整個人墜入深淵「咚
# 」一聲壓上人孔蓋，結界對撞當場破解掉雙閃與小闀。
#
#
#
# 完全阻絕水流的老宮主輕蔑一笑，「妖孽，毋囂掰。」
#
#
#
# 「哈哈，你找死啊，跑不了吧，你知道這樣水壓多大嘛！」
#
#
#
# 好像也是科學家的人面魚鼓起蹼爪鼓掌，雖然洪水不再湧入，但現場大量積水還是將堵出
# 水孔的老宮主與驅魔陣緊緊壓在水底，水壓過大，整個人如一顆塞子動彈不得。可于英雄
# 還是無動於衷，靜靜瞅著浤浤水中蛇魚像個參觀水族館的遊客。
#
#
#
# 「再見。」
#
#
#
# 睥睨滿池虎視眈眈的妖魔，于英雄左手指天，左腕銅錢也是七枚，剎那第二組七星驅魔陣
# 展開，範圍遠超精怪想像，「呼呼」大風吹過，廣闊琉璃大陣將整個淹水的中殿涵蓋入內
# ，緊接老宮主左手握拳一擺，第二層大陣劇烈內縮，如四面八方開來50台推土機，活生生
# 把氾濫成災的大水往內擠壓，高速回溯下水位節節攀升，五米、十米逾二十米拔地而起10
# 層樓高，化為一片直徑十米的琉璃圓柱建築。
#
#
#
# 水妖察覺不對已經太遲，迅速被推動的水流拉走，兩片七星鐵壁都敲不碎之下無力地被越
# 托越高，好像變成火鍋煮開浮上的貢丸跟蟹肉棒，破口大罵，「放我們出來，于英雄你這
# 民主白賊、渣男敗類、德不配位！」
#
#
#
# 中殿忽地豎起雙層陣法，如裝滿水的瓶中瓶，于英雄安全待在小瓶子裡，上一秒叫囂的臭
# 魚爛蝦全浮在夾層內，像雜質混濁濁隨波逐流，哀鴻遍野，蔚為奇觀。
#
#
#
# 「于老宮主，求求你放我們出去，不敢作惡啦……」
#
#
#
# 古銅幣咒．雙七星驅魔陣
#
#
#
# 「叫你們別膨風。」
#
#
#
# 于英雄所在的小瓶「唰」一下消失無蹤，如瞬間拔掉塞子的洗手台，「呼嚕嚕」清爽無比
# 的水流將這批妖魔全拉入龍捲漩渦，不到幾分鐘，通通流回地下道清潔溜溜，而以五鬼搬
# 運轉移的老宮主，又站回那座屹立不搖的香爐上傲視全場。
#
#
#
# 「沒擋頭。」
#
#
#
# 很多人說年近60歲的于英雄不行了，早就不是當年那一位北抗華家、南戰赤傘的浪花真人
# 。這幾年老宮主忙於制憲、忙於統合佛道、忙於建立民主大西部，多年未酣戰沙場，甫以
# 他自己頒布的「鬥法禁制令」，這些流言好像也合情合理。
#
#
#
# 但那些散布流言的臭嘴，如果現在在這會嚇傻閉嘴，開始信仰謠言止於智者。
#
#
#
# 「好厲害……」
#
#
#
# 連這些年浸於修行的司瑜，也不得不對這位百聞不如一見的前輩喝采，光他這一手將七星
# 驅魔陣發揮淋漓盡致，用專司防守的陣法眨眼擊退一池精銳精怪，就足以證明他還是當年
# 海天子的首席弟子，蔚藍南海之下最雄偉、最美麗的浪花。
#
#
#
# －－司瑜發現她需要時間，操之過急也沒用。而且還需要夥伴，可靠的夥伴。
#
#
#
# 于英雄緊急支援下危機解除，司瑜門咒重建大廟結界。
#
#
#
# 「眾生聞此號，俱來我剎中，如佛金色身，妙相悉圓滿。」
#
#
#
# 羅蠍王牌一出，樂園鬼牌登時失去效力，不到一柱香，正道就再次拿回主導權。擊退前殿
# 政變與中殿水攻，佛門僧人再次雙手合十，朗誦偈語聲越來越高昂。
#
#
#
#
#
#
#
# 叮鈴！
#
#
#
# 鈴聲如漣漪一圈一圈波動，遽然一道玄青與雪白風暴颳起，在場即使有千里眼的修士也只
# 能捕捉到一片模糊，懂行者曉得那是五鬼搬運陣所造成的高速殘影。
#
#
#
# 在佛鈴漣漪觸碰門王玉蘭空閬之時，必成正覺第七章畫上句點。18:06。
#
#
#
#
# 「亦以大悲心，利益諸群品，離欲深正念，淨慧修梵行。」
#
#
#
# 指揮中心內，岳熔扭動身子閃避到極限，威力削弱的狼爪掠過髮梢與衣角，削鐵如泥的乘
# 風胭脂滑過頸項和臉龐，但鋒利的天閂還是無法迴避砍入背項，總指揮被巨大衝擊力斬倒
# 在地，傘與狼再次攻上，門王玉蘭揮揮手，表情意猶未盡。
#
#
#
# 「永別了，總指揮官。」
#
#
#
# 咻！
#
#
#
# 破風聲揚起，四枚黑矢凌空摜破小紅傘，白暴風颳起，雪白僧袍懸於岳熔頭頂，霎時一絲
# 如魚鉤勒住狼魔大口，「嗖」地扯翻下順勢靠蛛絲彈力俯衝，近距離嗄嗄拉弓射殺另一頭
# 紅魔狼，同時疾如閃電踩上天閂，僧袍「剝」一聲撕裂下長出恐怖三頭六臂八足「轟」地
# 將門板狠狠踩入地面，頃刻三對強弩全數瞄準門神。
#
#
#
# 絲咒．黑弩弓
#
# 佛法．阿修羅
#
#
#
# 宛若奇蹟的一氣呵成，瀟灑登場的大施主半秒內如程咬金殺出，輕鬆處理乘風胭脂、紅狼
# 衛與門神連番夾殺，一來就逆轉全局。因兩年前「捕蠍計畫」而吃大虧的羅蠍折損一條手
# 臂後，痛定思痛，特針對這種連續咒密集訓練，此刻後來反先至，即使對手升級門神也難
# 不倒她。還是老生常談，努力的天才最為可怕。
#
#
#
# 「門阿婆，好久不見。」羅蠍氣定神閒，勾勾蛛絲牽動電閘，辦公室恢復大明。
#
#
#
# 「是有點久。」門王玉蘭微微瞇眼，緩緩嘆了一口氣，「你又變得更厲害。」
#
#
#
# 9月13號傍晚，大施主出手，恰如白駒過隙的救援行動，遏止樂園斬首行動，精妙計算下
# 成功策動樂園臥底的020902、佛門子弟兵與登天宮的于英雄，讓正準備簽署媾和的停戰協
# 議胎死腹中，出手抓得快狠準不愧對得「平天下」之名。
#
#
#
# 平天下出動，滅日行動終結。
#
#
#
#
#
# 「羅小姐，終於見到你啦！」
#
#
#
# 一旁被天閂斬殺，卻像沒事的岳熔拍拍軍服的沙塵起身，鋒利門板竟然只割開他的衣服，
# 在背上留下長條形瘀血而已，笑得有點帥，但很機掰。羅蠍不禁懷疑：這傢伙不會是故意
# 在這花式受困引佛門出手吧？他到底是用甚麼擋下天閂的？
#
#
#
# －－如當時打破沙鍋搞明白，冰清門將會千秋萬世。
#
#
#
# 「臭美，誰說我想見你，滾開，我心有所屬，你不要誘惑我喔，不會上當。」
#
#
#
# 可高傲的羅蠍只是咬牙轉頭。她深深有上當感覺，大佛門像是被他釣出來的。難受。
#
#
#
# 但今晚不出手還真的不行，如岳熔被斬殺或生擒，華煌明將全盤掌控部隊，爾後也沒有華
# 家了，首都會變第四塊封疆－－樂園北方華領主－－這是最糟糕的，赤傘獨霸北府與東方
# ，離「鷸蚌相爭」最遠：反成鷸蚌合體去捕殺漁翁。一切正道與魔道和平都對蜘蛛有害，
# 正邪越和諧、戰爭越少、彼此越接近統合，羅蠍就越沒法從中獲利。
#
#
#
# －－今夜和談是、半年後停戰是。十一年後必撕毀和平的「紅色星期六」亦然。
#
#
#
# 如活在人鬼統一的太平盛世，那何來亂可平定？沒有亂，何以成就平天下亂？
#
#
#
# 算了，就算給岳熔這大叔利用一回吧。羅蠍「哼」一聲，鼓起腮幫子。
#
#
#
# 「我還得回師院看表演，老太婆你啊再不撤，等等外頭會全軍覆……」
#
#
#
# 羅蠍講到一半就被門神縱聲長笑打斷，老阿嬤目光瞥到在室外伏擊的于英雄，如狐狸的眼
# 瞇成一線，「你們以為，樂園會完全沒準備就深入敵營？少年仔，還是太菜囉。」
#
#
#
# 她旋即解除身旁的暗閘，裡頭是一開場刺殺就藏好的一只大銀箱。是真正的鬼牌。
#
#
#
# 漂浮的小傘滔天狂笑，「一次性解決掉華、佛、道的大能首領才叫斬首啊，笨蛋！」
#
#
#
# 六道鎮之關．解
#
#
#
# 兩米立方銀箱「咚」地敞開，墨綠閃電猝然落在于英雄面前，正是被囚禁的大飛。
#
#
#
# 「小雄？」
#
#
#
# 叮噹叮噹噹……叮噹叮噹噹……
#
#
#
# 綿密金屬碰撞聲不絕於耳，將佛鈴完全掩蓋，此時的大飛渾身纏滿的紅繩線串起一圈又一
# 圈的古銅幣，好似一頭綠鏽色木乃伊，再看他一舉手、一投足，古銅幣根本不止是纏身上
# ，更多的早已割破佈滿老人斑的皮膚，嵌進一坨又一坨腥紅色血痂中，渾身噴出膿瘡的劇
# 烈腥羶臭，于英雄觀之不禁駭然，顫巍巍喊了出聲。
#
#
#
# 「師父、師父我來救……」
#
#
#
# 眼前老人根本不像是人類。更多古銅幣深深鑽進棗紅色肉中，將肌肉的紋理剁得亂七八糟
# 、發臭腐爛下爬滿蒼蠅與蟲蛆，更深的一些刺到深可見骨，老人的頭蓋骨就森森泛白，露
# 出大片骷髏，連瞎去窟窿雙眸也蓋上銅幣，但還是有一道陰毒目光穿透而來，森然吐出隻
# 字片語，「小雄，呵呵呵呵，師父、誰是你師父？」
#
#
#
# 悲戚的英雄想伸手，但眼前老人可怖到連不可一世的浪花真人也感到膽怯，大飛的雙眼明
# 明已供奉給「天」，但此刻他似乎還能瞧見一切，怒瞪為小猴子辯護的小鬼頭、最疼愛的
# 大弟子通通與蜘蛛站在一起，而弟子的銀耳環不復存在。
#
#
#
# －－不管任何人跟你借、偷、搶都不准交出，懂嗎？現在去把辦公桌收一收！
#
#
#
# 那就夠了，夠了。到頭來94歲的海天子這一生還是一無所成。就是個大笑話。
#
#
#
# 「你還當我是師父？竟跟歹人混在一起，替蜘蛛為禍人間，好、好、你好！」
#
#
#
# 曾經的道派海天子平舉雙手，一串串溶入肌肉纖維的銅幣血淋淋流淌，染綠的汙血滴答落
# 滿地，須臾「喀」一聲上膛巨響，這一響聽得令人骨髓都一陣陣發冷。
#
#
#
# 「老宮主，過來我這，你師父瘋了！」
#
#
#
# 羅蠍馬上施靈通咒，喚出佛家最堅固的「金剛輪觀音」上身，轉瞬一片金光轉輪浮現身前
# 護體，比日光燈閃耀百倍。在場沒人知道大飛要幹嘛，沒有左輪槍不可能是六御銃殺陣，
# 可所有高手都寒毛直立，感受山雨欲來，連門王玉蘭都心慌啟地閉，黑色圓柱將自己與小
# 紅傘嚴密護住，似乎唯有胭脂主見過此咒疾呼，「門老太，等等閃遠點！」
#
#
#
# 射出邪光的錢幣散發深邃的墨黑光澤，于英雄無聲哭號，恍若聾啞哀望老者。
#
#
#
# 叮！噹！
#
#
#
# 啊！
#
#
#
# 海天子雙手猛然爆炸，長嘯下無數古銅幣高速朝在場正道、魔道發射，銅幣中寄宿的神明
# 被一一榨乾殆盡，爆出數倍於六御銃殺槍的威力，有如雙手各安上一挺大飛小時最喜歡的
# 格林機關槍，無差別掃射室內，無人能反擊下鎮壓住全場。
#
#
#
# 「蜘蛛！」怒慟老人眼中只剩羅蠍。
#
#
#
# 叮噹噹噹噹噹噹噹噹噹噹噹噹噹噹！
#
#
#
# 牆壁、鐵櫃、座椅應聲中槍龜裂，子彈不僅威力驚人、源源不絕、且角度難測，看似直線
# 彈道在中途高速拐彎、反彈、瞬移到不可思議完全無法防禦的360個角度命中，滿臉火燙
# 燙的門王玉蘭目睹「魔陣」陡生，從未如此興奮。
#
#
#
# 「這就是入魔？」
#
#
#
# 道，就在錢幣裡。
#
#
#
# 曾有人說：擲錢幣不公平，機率不是一半一半，如你能知曉硬幣質量、出手的角度、力道
# 、摩擦、當下氣流與濕度等等大量資訊去瞬間運算出答案，近百分之百能得知硬幣落下的
# 正反，但人終究不是電腦，做不到的－－但「魔」能。如此時的大飛將百枚錢幣軌跡運算
# 完畢，何時五顆碰一起剎那轉移、轉移到那一點散開拉四角驅邪、驅邪時又撞成七顆豎驅
# 魔鐵壁，鐵壁反彈折射又恰排六枚一串。
#
#
#
# 全盤預測，盡收眼底，滿場狙擊、例無虛發。
#
#
#
# 鈴！
#
#
#
# 一枚子彈精準敲碎腰懸的佛鈴，大施主不禁咬牙，「抱歉，我趕不回去囉。」
#
#
#
# 子彈溶入四帝、五鬼、六御與七星，轉眼門王玉蘭的地閉被從腳下的死角打翻、堅固的金
# 剛輪遭開一整排洞貫穿、空閬直接炸成片片雪花飄落，司瑜緊急救援岳熔的天閂像餅乾般
# 脆弱，片晌間整個指揮中心就如被丟入一台柏青哥機，受困於小鋼珠的槍林彈雨下永無止
# 盡，剎那的組合拼湊，所有可能悉數計算，融會貫通於全知全能的魔性下，這一刻操魔陣
# 大飛已然超越所謂「修者」的範疇。
#
#
#
# 古銅幣咒．零始滅道陣
#
#
#
# 「死！」
#
#
#
# 生雞卵無，放雞屎有，這一生毫無意義還一敗塗地的阿公喊出此生最後一個字，想把這糟
# 蹋、遺棄、鄙視、栽贓他的一切毀滅，將「道」滅。一點不留情，連最固若金湯的雙七星
# 驅魔陣也被輕易輾成粉末粒子，火燙槍口最後指向于小雄額頭。
#
#
#
# 「師父……」
#
#
#
# 明明再上一階就得道成仙，明明為山九仞可功虧一簣，但他還是不願放棄，不放棄，又過
# 不了這道檻的人最後只能墮落，悟道則封神，滅道則入魔。一線之隔。
#
#
#
# 魔化大飛．誕臨
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 戴滿古銅幣的示意圖，取自香港電影"殭屍"(2013)
#
# https://imgur.com/ObNNJDo
#
# 如有雷同純屬巧合
#
#
#
#
#
#
#
#
#
#
#
#
# 啊~大家好，我是SKYOWL
#
# 三周年其實有好多話想說，很多人想感謝，但還是留給大家說，謝天吧!
#
# 有甚麼想說的，暢所欲言喔~
#
# 有問必答(應該)~
#
#
#
#
# 僅此紀念2017.5.30~2020.5.29
#
# 希望第四年已把後傳寫完。沒餓死的話XD
#
#
#
#
#
#
# 未經授權者，不得將文章用於各種商業用途
#
# 勿入里和村。貓頭鷹:)

# %%
IP_address = main_text.split('來自:')[1].split("\n")[0]
IP_address
# Out:
# ' 114.45.151.48 (臺灣)'

# %% [markdown]
# ```
# f"{article_id}" = {
#     "Date" : ""
#     "Title" : ""
#     "Author" : ""
#     "IP" : ""
#     "Content" :
# }
# ```

# %%
f"{article_id}"
# Out:
# '1590730337'

# %%
exec_str = "M" + f"{article_id}"
exec_str
# Out:
# 'M1590730337'

# %%
exec(exec_str+" = {}", globals())

# %%
exec(f"{exec_str}", globals())

# %% [markdown]
# ## 實作：把搜尋頁第一頁的文章都爬下來，存在一個dict內

# %%
#忽略warning
import warnings
warnings.filterwarnings('ignore')

# 建立字典
earthquake_dict = {} # key是文章的link，value是另一本以文章的unique link為名的dict
# list內則有：發文時間、文章標題、作者ID、作者IP、文章內容
names = globals()

# 搜尋頁面換頁
# https://www.ptt.cc/bbs/marvel/search?page=1&q=recommend%3A100
# key換成index
index = 1
for page_count in range(1, 139+1): #139頁
    search_page_url = "https://www.ptt.cc/bbs/marvel/search?page=" + str(page_count) + "&q=recommend%3A100"
    resp = requests.get(search_page_url, headers = header_over18)
    soup = BeautifulSoup(resp.text, "html.parser")
    
    # 找到該搜尋頁面下 全部地震文章的連結
    titles = soup.find_all("div", "title") #找到每篇文章的標題及連結
    for title in titles:
        #print(title.text, title.a["href"])
        
        link = "https://www.ptt.cc/" + title.a["href"]
        #article_id = title.a["href"].split(sep = "/")[-1].split(sep = ".")[1]
        article_id = index
        index+=1
        
        #為這篇文章建一個dictionary
        name_str = "M" + f"{article_id}"
        names["M_%s" %article_id] = {}
        earthquake_dict[name_str] = names["M_%s" %article_id]

        
        # 進入搜尋頁面的第一篇文章
        payload = {
            "from" : "/bbs/Gossiping/index.html",
            "yes"  : "yes"
        }
        rs = requests.session()
        res_subpage = rs.post("https://www.ptt.cc/ask/over18", verify = False, data = payload)
        res_subpage = rs.get(link, verify = False)
        soup_subpage = BeautifulSoup(res_subpage.text, "html.parser")

        #一篇文章的 作者、標題、時間、看板
        header = soup_subpage.find_all("span", "article-meta-value")
        #print(header)
        #print(header[0].text) #author
        #print(header[1].text) #board
        #print(header[2].text) #title
        #print(header[3].text) #date
        
        try: #如果有「看板」的話
            names["M_%s" %article_id]["Author"] = header[0].text
            names["M_%s" %article_id]["Board"] = header[1].text
            names["M_%s" %article_id]["Title"] = header[2].text
            names["M_%s" %article_id]["Date"] = header[3].text
        except:
            try: #如果是回覆文章，沒有「看板」的話
                names["M_%s" %article_id]["Author"] = header[0].text
                names["M_%s" %article_id]["Title"] = header[1].text
                names["M_%s" %article_id]["Date"] = header[2].text
            except:
                pass

        # 內文
        try:
            main_text = soup_subpage.find(id = "main-container").text
        except:
            pass
        #print(main_text)
        # 把整個內容切割透過 "-- " 切割成2個陣列
        pre_text = main_text.split('--')[0]
        # 把每段文字 根據 '\n' 切開
        texts = pre_text.split('\n')
        # 如果你爬多篇你會發現 
        contents = texts[2:]
        # 內容
        content = '\n'.join(contents)
        #print('內容：'+content)
        names["M_%s" %article_id]["Content"] = content

        
        #IP位址
        try:
            try:
                IP_address = main_text.split('來自:')[1].split("\n")[0]
                #print(IP_address)
                names["M_%s" %article_id]["Full IP"] = IP_address
            except:
                try:
                    author = header[0].text
                    authorID = author.split(sep = " (")[0]
                    #print(main_text.split(sep = authorID)[2].split(sep = "),")[0].split()[0][1:])
                    IP_address = main_text.split(sep = authorID)[2].split(sep = "),")[0].split()[0][1:]
                    names["M_%s" %article_id]["Full IP"] = IP_address
                except:
                    pass
        except:
            names["M_%s" %article_id]["Full IP"] = "Not Found"
        
        #只有數字的IP
        try:
            IP_shorten = IP_address.split(sep = " ")[1]
            names["M_%s" %article_id]["IP"] = IP_shorten
        except:
            pass
        
        # 推文
        try:            
            push = main_text.split(sep = "html")[1].split(sep = "\n")[1:]
            names["M_%s" %article_id]["Push"] = push
        except:
            names["M_%s" %article_id]["Push"] = "No Push"
        
        
        # 推、噓、箭頭數
        # push count
        pushCount = 0
        for i in soup_subpage.find_all("span", {'class' : 'hl push-tag'}):
            if "推" in i.get_text():
                pushCount+=1
        names["M_%s" %article_id]["PushCount"] = pushCount
        
        # boo count
        BooCount = 0
        for i in soup_subpage.find_all("span", {'class' : 'f1 hl push-tag'}):
            if "噓" in i.get_text():
                BooCount+=1
        names["M_%s" %article_id]["BooCount"] = BooCount
        
        # arrow count
        ArrowCount = 0
        for i in soup_subpage.find_all("span", {'class' : 'f1 hl push-tag'}):
            if "→" in i.get_text():
                ArrowCount+=1
        names["M_%s" %article_id]["ArrowCount"] = ArrowCount
        
        time.sleep(0.1)

# %%
title
# Out:
# <div class="title">
# <a href="/bbs/marvel/M.1044470839.A.html">殭屍</a>
# </div>

# %%
header[0]
# Out:
# <span class="article-meta-value"><a class="__cf_email__" data-cfemail="62010a0b0e06074c000011220000114c07164c0c161711164c0706174c1615" href="/cdn-cgi/l/email-protection">[email protected]</a> (綠樂團-冷花),</span>

# %%
author = header[0].text
authorID = author.split(sep = " (")[0]
#print(main_text.split(sep = authorID)[2].split(sep = "),")[0].split()[0][1:])

# %%
authorID
# Out:
# '[email\xa0protected]'

# %%
page_count
# Out:
# 139

# %%
len(earthquake_dict)
# Out:
# 2772

# %%
earthquake_dict.keys()
# Out:
# dict_keys(['M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'M10', 'M11', 'M12', 'M13', 'M14', 'M15', 'M16', 'M17', 'M18', 'M19', 'M20', 'M21', 'M22', 'M23', 'M24', 'M25', 'M26', 'M27', 'M28', 'M29', 'M30', 'M31', 'M32', 'M33', 'M34', 'M35', 'M36', 'M37', 'M38', 'M39', 'M40', 'M41', 'M42', 'M43', 'M44', 'M45', 'M46', 'M47', 'M48', 'M49', 'M50', 'M51', 'M52', 'M53', 'M54', 'M55', 'M56', 'M57', 'M58', 'M59', 'M60', 'M61', 'M62', 'M63', 'M64', 'M65', 'M66', 'M67', 'M68', 'M69', 'M70', 'M71', 'M72', 'M73', 'M74', 'M75', 'M76', 'M77', 'M78', 'M79', 'M80', 'M81', 'M82', 'M83', 'M84', 'M85', 'M86', 'M87', 'M88', 'M89', 'M90', 'M91', 'M92', 'M93', 'M94', 'M95', 'M96', 'M97', 'M98', 'M99', 'M100', 'M101', 'M102', 'M103', 'M104', 'M105', 'M106', 'M107', 'M108', 'M109', 'M110', 'M111', 'M112', 'M113', 'M114', 'M115', 'M116', 'M117', 'M118', 'M119', 'M120', 'M121', 'M122', 'M123', 'M124', 'M125', 'M126', 'M127', 'M128', 'M129', 'M130', 'M131', 'M132', 'M133', 'M134', 'M135', 'M136', 'M137', 'M138', 'M139', 'M140', 'M141', 'M142', 'M143', 'M144', 'M145', 'M146', 'M147', 'M148', 'M149', 'M150', 'M151', 'M152', 'M153', 'M154', 'M155', 'M156', 'M157', 'M158', 'M159', 'M160', 'M161', 'M162', 'M163', 'M164', 'M165', 'M166', 'M167', 'M168', 'M169', 'M170', 'M171', 'M172', 'M173', 'M174', 'M175', 'M176', 'M177', 'M178', 'M179', 'M180', 'M181', 'M182', 'M183', 'M184', 'M185', 'M186', 'M187', 'M188', 'M189', 'M190', 'M191', 'M192', 'M193', 'M194', 'M195', 'M196', 'M197', 'M198', 'M199', 'M200', 'M201', 'M202', 'M203', 'M204', 'M205', 'M206', 'M207', 'M208', 'M209', 'M210', 'M211', 'M212', 'M213', 'M214', 'M215', 'M216', 'M217', 'M218', 'M219', 'M220', 'M221', 'M222', 'M223', 'M224', 'M225', 'M226', 'M227', 'M228', 'M229', 'M230', 'M231', 'M232', 'M233', 'M234', 'M235', 'M236', 'M237', 'M238', 'M239', 'M240', 'M241', 'M242', 'M243', 'M244', 'M245', 'M246', 'M247', 'M248', 'M249', 'M250', 'M251', 'M252', 'M253', 'M254', 'M255', 'M256', 'M257', 'M258', 'M259', 'M260', 'M261', 'M262', 'M263', 'M264', 'M265', 'M266', 'M267', 'M268', 'M269', 'M270', 'M271', 'M272', 'M273', 'M274', 'M275', 'M276', 'M277', 'M278', 'M279', 'M280', 'M281', 'M282', 'M283', 'M284', 'M285', 'M286', 'M287', 'M288', 'M289', 'M290', 'M291', 'M292', 'M293', 'M294', 'M295', 'M296', 'M297', 'M298', 'M299', 'M300', 'M301', 'M302', 'M303', 'M304', 'M305', 'M306', 'M307', 'M308', 'M309', 'M310', 'M311', 'M312', 'M313', 'M314', 'M315', 'M316', 'M317', 'M318', 'M319', 'M320', 'M321', 'M322', 'M323', 'M324', 'M325', 'M326', 'M327', 'M328', 'M329', 'M330', 'M331', 'M332', 'M333', 'M334', 'M335', 'M336', 'M337', 'M338', 'M339', 'M340', 'M341', 'M342', 'M343', 'M344', 'M345', 'M346', 'M347', 'M348', 'M349', 'M350', 'M351', 'M352', 'M353', 'M354', 'M355', 'M356', 'M357', 'M358', 'M359', 'M360', 'M361', 'M362', 'M363', 'M364', 'M365', 'M366', 'M367', 'M368', 'M369', 'M370', 'M371', 'M372', 'M373', 'M374', 'M375', 'M376', 'M377', 'M378', 'M379', 'M380', 'M381', 'M382', 'M383', 'M384', 'M385', 'M386', 'M387', 'M388', 'M389', 'M390', 'M391', 'M392', 'M393', 'M394', 'M395', 'M396', 'M397', 'M398', 'M399', 'M400', 'M401', 'M402', 'M403', 'M404', 'M405', 'M406', 'M407', 'M408', 'M409', 'M410', 'M411', 'M412', 'M413', 'M414', 'M415', 'M416', 'M417', 'M418', 'M419', 'M420', 'M421', 'M422', 'M423', 'M424', 'M425', 'M426', 'M427', 'M428', 'M429', 'M430', 'M431', 'M432', 'M433', 'M434', 'M435', 'M436', 'M437', 'M438', 'M439', 'M440', 'M441', 'M442', 'M443', 'M444', 'M445', 'M446', 'M447', 'M448', 'M449', 'M450', 'M451', 'M452', 'M453', 'M454', 'M455', 'M456', 'M457', 'M458', 'M459', 'M460', 'M461', 'M462', 'M463', 'M464', 'M465', 'M466', 'M467', 'M468', 'M469', 'M470', 'M471', 'M472', 'M473', 'M474', 'M475', 'M476', 'M477', 'M478', 'M479', 'M480', 'M481', 'M482', 'M483', 'M484', 'M485', 'M486', 'M487', 'M488', 'M489', 'M490', 'M491', 'M492', 'M493', 'M494', 'M495', 'M496', 'M497', 'M498', 'M499', 'M500', 'M501', 'M502', 'M503', 'M504', 'M505', 'M506', 'M507', 'M508', 'M509', 'M510', 'M511', 'M512', ' ...

# %%
earthquake_dict["M3"]
# Out:
# {'Author': 'gn02602057 (攤)',
#  'Board': 'marvel',
#  'Title': '[創作] 詭誌-殺人夢魔(5)完',
#  'Date': 'Wed Jun 17 06:00:53 2020',
#  'Content': '\n\n\n\n「做好準備了嗎？」\n\n我從臥室裡走出來，對正在客廳裡看電視的書池問道。\n\n電視螢幕上正在用PS4連接串流平台，播放《謀殺進修課》的最後一集，現在剛好演完進\n入片尾名單，書池用手把將PS4關機，同時也拿起遙控器關掉電視。\n\n書池的表情雖然維持得很鎮定，但他按在PS4手把上的手指卻持續在發抖，每次在遊戲中\n準備要打大BOSS的時候，我的手指也會有這樣的反應，因為緊張是藏不住的。\n\n對書池來說，今天晚上的睡眠絕對是他二十年人生中最重要的一次。\n\n因為藉由今天晚上的夢境，我們就要把夢裡的書池跟詩媛從惡夢裡解救出來。\n\n書池今天晚上會在我家的客廳過夜，我在旁邊隨時注意他的情況，夜貓子則留在詩媛家陪\n她過夜，同樣隨時觀察詩媛入睡後的情形。\n\n會這樣分隔兩地執行，主要是因為詩媛堅持要留在自己家裡，而夜貓子也幫詩媛背書，她\n說：「讓詩媛留在家裡的話，對我們今晚的計畫會有非常大的幫助，所以就分開來實施吧\n。」\n\n夜貓子這麼說的原因是什麼，我當下並不知道，直到這起事件結束那一刻，我才知道真相\n為何。\n\n書池把PS4的手把放回主機旁邊後，他坐回沙發上問：「等一下睡覺的時候，我只要一直\n想著……等一下我會是在作夢、等一下
只是他在夢中早一步發現自己是在作夢，所以可以為所欲為，他似乎也\n用了心理暗示的方法來讓自己每天可以回到夢境裡，不過他不打算讓這個夢太快結束，而\n是刻意延緩夢境來享受殺人的快感。」\n\n被害者的惡夢就是兇手的美夢，要是我作了一個能控制一切的清醒夢，我也會希望多夢幾\n天，在裡面好好享受那種感覺。\n\n「當然還有另一種可能，就是詩媛的潛意識發出的求救訊息成功拖延了時間，她也在那個\n空間裡努力地把自己跟你藏起來不被兇手找到，直到現實世界的詩媛把訊息投稿到詭誌、\n你也看到了她的投稿而來到這裡，這些要素都達成後，詩媛的潛意識就無法再拖延下去了\n，如果這場夢境是一部影集，那今天晚上的夢可能就是最後一集了。」\n\n書池似懂非懂地點著頭，說：「只是，夢中的我們竟然跟現實裡的我們求救，這聽起來真\n的好玄呀……」\n\n「關於夢境，無法解釋的事情還很多呢，你又怎麼知道我們這裡就是現實世界呢？搞不好\n地球的存在也只是一場夢也說不定呢。」我從沙發上站起來，說：「總之，要是哪天輪到\n我們發生意外，在即將死去的時候卻發現還有另一個世界的自己存在著，我們也一定會努\n力去求救的，就像夢中的你跟詩媛一樣。」\n\n我所要表達的情境太過抽象，書池一下聽傻了，我拍了拍蓋在他身上的毛毯說：「我先回\n房間忙，等你睡著之後，我就只能在現實世界這邊幫你加油了，晚安。」\n\n「好，風海老師晚安囉。」書池甩甩頭，整理好思緒後把頭埋到毛毯當中，嘴巴裡喃喃唸\n著：「等一下我是在作夢……等一下我是在作夢……」\n\n我把客廳的燈關掉，回到房間裡坐回電腦前面，電腦螢幕上仍開著好幾個網頁，都是跟夢\n境有關的各種研究資料，我已經把這些網頁都看過一遍了，但是顯然的，靠人類目前的知\n識仍無法真正觸碰到夢境裡的世界。\n\n我想到那位兇手，他雖然每天都想回到夢裡殺掉書池跟詩媛，可惜進度似乎無法如他所願\n，夢中的詩媛跟書池仍活著，但也只剩最後一口氣了。\n\n他們能不能活下去，就看今天晚上了。\n\n當兇手這次發現書池跟詩媛也有同樣的力量能反抗時，不知道他會怎麼想呢？\n\n花了約莫半小時的時間把夢境相關的資料又看了一遍，等我再走出臥室時，毛毯中的書池\n已經發出輕微的鼾聲，睡著了。\n\n我從冰箱裡拿出咖啡，坐回個人座沙發上靜靜看著書池，在看似安穩的睡眠中，不知道書\n池的意識是不是已經回到《謀殺進修課》的教室裡，準備接管潛意識來跟兇手對抗了？\n\n不過書池才剛入睡，應該不會這麼快就作夢，就算已經在作夢了，也不一定能馬上回到《\n謀殺進修課》的夢裡，平均來說，人類一個晚上會作五個夢，最多還能達到二十個，只是\n人們通常只能記住醒來前的一、兩個夢境。\n\n雖然喝了咖啡，但放鬆下來的情緒還是讓我的身體彷彿化成一灘爛泥，完全陷在沙發裡。\n\n我原本想用遊戲跟電影來打發深夜的時間，但有打過瞌睡的人都知道，當處於這種要睡不\n睡的狀態時，只要一閉上眼睛，就是宣告輸給睡魔了。\n\n而我正是這個時刻閉上了眼睛，我的意識就像關機一樣，被睡魔拖入黑暗中。\n\n\n\n\n\n\n******\n\n\n除非有人在旁邊幫忙觀察，不然每個人應該都沒看過自己睡覺時的情況，更不會聽到自己\n的鼾聲跟夢話內容。\n\n我不曉得自己睡著後會不會說夢話，但有時夢到一些激烈、需要喊叫的場景時，我彷彿也\n能在夢裡聽見自己的聲音，因此而驚醒過來。\n\n但這次，我並不是被自己的夢話嚇醒的，而是聽到書池發出的詭異呢喃聲而醒過來的。\n\n睜開眼睛的時候，我的身體仍維持著打瞌睡時的姿勢，整個人陷在沙發裡，喝到一半的咖\n啡還放在大腿上，這段時間咖啡沒有掉到地上真是一個奇蹟。\n\n書池的表情看起來極為痛苦，他斷斷續續說出幾個不清楚的字眼：「唔啊……放……放開\n……你……放開她……」\n\n我看了一下時鐘，清晨四點五十分，正是夢境在腦中最活躍的時間，看來書池已經成功讓\n主意識進入夢中，正在跟兇手展開戰鬥。\n\n「書池已經開始了，妳那邊呢？」\n\n我把訊息傳送給夜貓子，夜貓子似乎一直保持清醒，因為她很快就回覆了：「詩媛睡得很\n熟，目前沒有異樣。」\n\n難道詩媛的主意識還沒有在夢境裡覺醒？也就是說現在只有書池在夢境裡戰鬥……只靠他\n一個人的力量，足夠戰勝兇手嗎？\n\n雖然還沒有科學能夠證明，但是人的意識在夢境中究竟能發揮多少力量，我認為關鍵在於\n意志力跟精神力，只希望書池體內擁有的是一個跟他的斯文外表相反的強大意志。\n\n我在沙發上將兩手十指緊緊相握，咬著牙說：「書池，你一定要贏呀……」\n\n這是我目前唯一能做的了，要是哆啦A夢真的存在的話，我恨不得現在馬上把哆啦A夢從抽\n屜裡抓出來，然後叫他把可以看見夢境的道具給我拿出來，我記得海綿寶寶也有類似的劇\n情，有一集是海綿寶寶在睡著之後跑到其他人的夢境裡到處搗亂……就在我藉由胡思亂想\n來放鬆緊繃的情緒時，書池突然醒了過來。\n\n書池的雙眼用力睜開來，整個身體就像被高壓電電到一樣在沙發上劇烈抽搐，力道之大讓\n整個沙發都往後移位了。\n\n「詩媛……詩媛……要快點去救詩媛才可以……」書池似乎沒意識 ...
#  'Full IP': ' 110.50.160.101 (臺灣)',
#  'IP': '110.50.160.101',
#  'Push': ['推 hl9066: 推推06/17 06:02',
#   '推 qqeww5789: 二推～06/17 06:03',
#   '推 girl77711: 三推～06/17 06:04',
#   '推 piggyhawk: 四推～ 06/17 06:05',
#   '推 hsuan7587: 推06/17 06:09',
#   '推 gin1998048: 難得前十推06/17 06:11',
#   '推 ennn: 七推 06/17 06:12',
#   '推 yu800910: 推06/17 06:14',
#   '推 carolmeat: 推06/17 06:17',
#   '推 viviiss: 前十推推06/17 06:17',
#   '推 ura87: 推!06/17 06:18',
#   '推 ericdoctor: 先推再看！！！06/17 06:21',
#   '推 mema711: 推06/17 06:21',
#   '推 ePaper: 推 好快06/17 06:24',
#   '推 wan0725: 推06/17 06:32',
#   '推 childgarden: 早起看完 推06/17 06:35',
#   '推 kbgarnett: 20推內06/17 06:38',
#   '推 JER2725: 推06/17 06:41',
#   '推 lenuage2: 推06/17 06:41',
#   '推 nightwalker: 題材是有趣的 可是這個收尾有點倉促的感覺 06/17 15:55',
#   '推 spadeg25620: 詩媛書池會變常態角色嗎哈哈 06/17 16:15',
#   '推 Primk:  推~~~ 攤大就是讚 06/17 16:19',
#   '推 eastpopo: 很多事情沒交代就突然結束的感覺 06/17 16:20',
#   '推 A11pass: 推 06/17 16:44',
#   '推 jingne14: 推！！ 06/17 16:49',
#   '推 Snowyc: 推 06/17 17:24',
#   '推 yui2307: 題材很有趣06/17 17:30',
#   '推 lych9520487: 推 06/17 17:37',
#   '→ Rephel: 推!! 06/17 17:53',
#   '推 elaine4444: 推 06/17 18:10',
#   '推 sukinoneko: 結尾倉促了些，謝謝攤大 06/17 18:19',
#   '推 Legolasgreen: 推 06/17 18:51',
#   '推 holymoly: 推!! 06/17 18:53',
#   '推 daniel612662: 推 06/17 18:53',
#   '推 ePaper: 感覺這會有續作 兇手也沒有真正出現 06/17 19:14',
#   '這篇並不會有續集了喔，其實兇手的真實身份並不重要，因為他其實就是我們每一個人的',
#   '化身，因為我們每個人也都曾經想用夢境來發洩現實中的壓力，也就是說我們都是兇手',
#   '推 Kidking: 推，祝新書大賣 06/17 19:40',
#   '推 nigi0309: 加一個《完》超讚的，我習慣一章完結才一起看，之前沒 06/17 19:56',
#   '→ nigi0309: 有標示，都得進去看留言有沒有敲碗才知道結束沒，但偶 06/17 19:56',
#   '→ nigi0309: 爾會被爆雷T.T 06/17 19:56',
#   '推 gg85811: 推 06/17 19:58',
#   '※ 編輯: gn02602057 (59.126.108.5 臺灣), 06/17/2020 20:11:37',
#   '推 s3893616: 推 06/17 20:15',
#   '推 youaremyall: 推推推 06/17 20:19',
#   '推 hmhuang: 推 06/17 20:40',
#   '推 punipuan: 推 06/17 20:51',
#   '推 summer3965: 推 06/17 20:54',
#   '推 techwall: 推！！ 06/17 20:58',
#   '推 IBERIC: 推！ 06/17 21:20',
#   '推 ltyintw: 推 06/17 21:33',
#   '推 t6203leo: Push 06/17 21:45',
#   '推 beastwolf: 推 06/17 21:59',
#   '推 orangeplay: 推 06/17 22:18',
#   '推 bluesea1106: 好有趣！推！ 06/17 22:41',
#   '推 pricessyo: 推 06/17 23:54',
#   '→ dianagao: 想請問不是主角睡覺後潛意識才會醒來嗎？如果潛意識一 06/18 00:03',
#   '→ dianagao: 直都醒著，感覺只是活在不同空間的我們 06/18 00:03',
#   '推 huhhuh: 推 06/18 00:47',
#   '推 yeana0428: 推～～ 06/18 01:24',
#   '推 xxxatyt: 推 想不到的結局 好棒 06/18 02:31',
#   '推 yanghala: 推推 06/18 03:53',
#   '推 ridle: 追完惹！推推！~~ 06/18 04:52',
#   '推 ePaper: 好喔 題材蠻新穎的 06/18 08:22',
#   '推 jin956: 很勵志 睡覺也能認識異性 肥宅們洗洗睡囉 06/18 08:36',
#   '推 eathihi: 推！ 06/18 09:26',
#   '推 Anectre: 推! 06/18 11:51',
#   '推 Wasfhi: 推 06/18 12:02',
#   '推 waft25: 未看先推！ 06/18 14:10',
#   '推 admission78: 推！這次的故事也太可愛了～～ 06/18 15:25',
#   '推 bobo41130: 推 06/18 16:45',
#   '推 Kelvinchen: 推 06/18 19:59',
#   '推 weasley47: 推啊啊啊啊 06/18 23:10',
#   '推 warmbee: 推 06/19 00:03',
#   '推 ac147896: 看來兇手中了伊邪那美!!!!!! 06/19 03:32',
#   '→ ac147896: 詩媛也是會萬花筒血輪眼的 06/19 03:33',
#   '推 balloons: 推 06/19 03:53',
#   '推 athena426: 所以手機為什麼會出現影片 還會消失呢？ 06/19 07:18',
#   '推 raxway: 收尾有夠倉促 小失望 06/19 08:18',
#   '推 kayyang: 推 06/19 09:02',
#   '推 pithew: 推～ 06/20 17:02',
#   '推 kiteqo6: 夢中npc要轉化成現實cp了 06/21 02:51',
#   '→ kickyjump: 攤大的題材總是很特別，但為什麼一定都要強調女生是美 06/21 09:43',
#   '→ kickyjump: 女啊？而且敘述的方式就真的只強調美，並沒有讓女生的 06/21 09:43',
#   '→ kickyjump: 形象更鮮明，然後對男生的外貌形象也都草草帶過，然後 06/21 09:43',
#   '→ kickyjump: 也都不是帥哥（？），閱讀體驗時常被截斷好難過啊QQ 06/21 09:43',
#   '推 rapnose: 感覺可以寫一個Abby Anderson。 06/21 15:30',
#   '推 a9081212071: 這集我真的沒辦法...... 06/21 16:04',
#   '',
#   '',
#   ''],
#  'PushCount': 191,
#  'BooCount': 0,
#  'ArrowCount': 10}

# %%
IP_shorten = IP_address.split(sep = " ")[1]
IP_shorten
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-113-72354e4ac805> in <module>()
# ----> 1 IP_shorten = IP_address.split(sep = " ")[1]
#       2 IP_shorten
#
# IndexError: list index out of range

# %% [markdown]
# # Save Dictionary

# %%
# Save
np.save("marvel_爆文", earthquake_dict)

# Load
#read_dictionary = np.load('my_file.npy',allow_pickle='TRUE').item()

# %%
earthquake_dict["M2767"]
# Out:
# {'Author': 'doll1324 (不信為何要轉錄呢)',
#  'Board': 'marvel',
#  'Title': '[豪洨]黑令旗千年劫(8) ',
#  'Date': 'Sat Mar 11 18:07:09 2006',
#  'Content': '\n<前言>\n\n雖然說是[真實]，不過還是照例改成[豪洨]。請勿轉去唬爛版謝謝m(_ _)m\n\n請勿任意轉錄，無論是PTT站內或個人版網誌都一樣喔:)\n\n\n\n\n\n<聲明>\n\n嗯，還請大家高抬貴手，\n\n不用特地轉去哪，然後另開專門罵我胡扯、或斬釘截鐵指責的文章。\n\n\n對於前輩我一向抱持著敬意，但無意與任何人筆戰，\n\n我不是伶姬2號，大家也不用當張開基特別撰文來唾罵，\n\n小女子平日興趣是睡覺打電動，志願是作科學研究，\n\n能力很差現在又被禁，(強調很多次了orz)\n\n不僅無能，也不想搶任何人飯碗。真的。XD\n\n\n請各位強的像一面牆的高人前輩，手下留情不要為難我，\n\n不論明的暗的文的武的方法都一樣。\n\n\n\n\n\n只是想跟大家分享，當時不懂事的無形界奇遇而已:)\n\n\n\n\n',
#  'Full IP': '不要只推，我想聽感想啊啊orz...',
#  'Push': 'No Push',
#  'PushCount': 161,
#  'BooCount': 0,
#  'ArrowCount': 18}
